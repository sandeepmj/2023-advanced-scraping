# %% [markdown]
# # Scraping APIs
#
# A site with an API (Application Programming Interface) wants you to scrape it.
#
# Examples abound:
#
# * <a href="https://www.census.gov/data/developers/data-sets.html">U.S. Census APIs</a>
# * <a href="https://apps.fas.usda.gov/opendataweb/home">US Agriculture Commodities and Exports</a>
# * <a href="https://www.federalregister.gov/developers/documentation/api/v1">Federal Register</a>
# * <a href="https://developer.dol.gov/beginners-guide/">Labor Department</a>
# * <a href="https://www.eia.gov/">Labor Department</a>
#
# Government sites tend  ```CSVs``` for download but their APIs offer more detailed options for data. They are not trying to hide the data.
#
# Private sites might have APIs, but often charge heafty prices for access beyond a basic number of downloads.
#
# The toughest/hardest part of scraping an API is that they ***ALL HAVE DIFFERENT INSTRUCTIONS*** on how to tap their data.
#
# Today, we'll explore different APIs that each build a different skill:
#
# 1. Census health data – **building a simple API call.**
# 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
# 3. Federal Register – **tapping search terms.**
# 4. Energy Information Administration – **dealing with pagination.**
#
# What they all have in common:
#
# 1. a base url
# 2. a query string
# 3. tied together with a query character ```?```
# 4. an API key.
#
# Combined together these are known as an ```API endpoint```.
#
# You make an ```API call``` (a request) using the ```API endpoint```.

# %%
pip install icecream
# Out:
# Requirement already satisfied: icecream in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (2.1.2)
# Requirement already satisfied: colorama>=0.3.9 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from icecream) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from icecream) (2.15.1)
# Requirement already satisfied: executing>=0.3.1 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from icecream) (0.8.3)
# Requirement already satisfied: asttokens>=2.0.1 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from icecream) (2.0.5)
# Requirement already satisfied: six in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from asttokens>=2.0.1->icecream) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
## import libraries
import requests
import pandas as pd
from icecream import ic

# %% [markdown]
# ### 1. Census health data – **building a simple API call.**
#
# - <a href="https://www.census.gov/data/developers/data-sets/Health-Insurance-Statistics.html">Census health landing page</a>
# - List of <a href="https://api.census.gov/data/timeseries/healthins/sahie/variables.html">possible variables</a>
#
# We want to create a dataframe with the following info for every state in 2021:
#
# 1. Total number insured
# 2. Percent insured
# 3. Total number uninsured
# 4. Percent uninsured
# 5. Broken down by race

# %% [markdown]
# ## the parts to build your API endpoint.

# %%
## create a dictionary to know what codes mean
target_dict = {
    "NIC_PT": "total_insured",
    "PCTIC_PT": "pct_insured_est",
    "NUI_PT": "total_uninsured",
    "PCTUI_PT": "pct_uninsured_est",
    "RACECAT": "race_category",
    "RACE_DESC": "race_description",
    "STABREV": "state"
    
}

# %%
## keys() to get keys
list(target_dict.keys())
# Out:
# ['NIC_PT', 'PCTIC_PT', 'NUI_PT', 'PCTUI_PT', 'RACECAT', 'RACE_DESC', 'STABREV']

# %%
## values() to get val;;ues
list(target_dict.values())
# Out:
# ['total_insured',
#  'pct_insured_est',
#  'total_uninsured',
#  'pct_uninsured_est',
#  'race_category',
#  'race_description',
#  'state']

# %%
## format into api query format
my_vars = ",".join(target_dict.keys())
my_vars
# Out:
# 'NIC_PT,PCTIC_PT,NUI_PT,PCTUI_PT,RACECAT,RACE_DESC,STABREV'

# %%
## endpoint
base_url = "https://api.census.gov/data/timeseries/healthins/sahie?get="
target_year = "2021"

# %%
## create query string
query_str = f"{my_vars}&for=state:*&time={target_year}"
query_str
# Out:
# 'NIC_PT,PCTIC_PT,NUI_PT,PCTUI_PT,RACECAT,RACE_DESC,STABREV&for=state:*&time=2021'

# %%
## create full API call
endpoint = base_url + query_str
endpoint
# Out:
# 'https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_PT,PCTIC_PT,NUI_PT,PCTUI_PT,RACECAT,RACE_DESC,STABREV&for=state:*&time=2021'

# %%
## get response
response = requests.get(endpoint)

# %%
## turn response into json
data = response.json()
data
# Out:
# [['NIC_PT',
#   'PCTIC_PT',
#   'NUI_PT',
#   'PCTUI_PT',
#   'RACECAT',
#   'RACE_DESC',
#   'STABREV',
#   'time',
#   'state'],
#  ['3548525', '88.3', '469887', '11.7', '0', 'All Races', 'AL', '2021', '01'],
#  ['2293718',
#   '90.0',
#   '254385',
#   '10.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['921007',
#   '87.1',
#   '135939',
#   '12.9',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['163769',
#   '73.3',
#   '59615',
#   '26.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AL',
#   '2021',
#   '01'],
#  ['13274',
#   '83.7',
#   '2587',
#   '16.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['57789',
#   '89.8',
#   '6551',
#   '10.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['1784',
#   '84.9',
#   '317',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['97184',
#   '90.3',
#   '10493',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['530325', '86.8', '80538', '13.2', '0', 'All Races', 'AK', '2021', '02'],
#  ['319149',
#   '90.1',
#   '35072',
#   '9.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['16652',
#   '85.9',
#   '2726',
#   '14.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['40054',
#   '79.6',
#   '10266',
#   '20.4',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AK',
#   '2021',
#   '02'],
#  ['52439',
#   '74.8',
#   '17628',
#   '25.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['34159',
#   '87.4',
#   '4903',
#   '12.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['8269',
#   '83.6',
#   '1624',
#   '16.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['59603',
#   '87.8',
#   '8319',
#   '12.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['5016330', '86.9', '758331', '13.1', '0', 'All Races', 'AZ', '2021', '04'],
#  ['2540419',
#   '91.8',
#   '228172',
#   '8.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['246304',
#   '88.7',
#   '31477',
#   '11.3',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['1704504',
#   '80.5',
#   '411965',
#   '19.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AZ',
#   '2021',
#   '04'],
#  ['131074',
#   '73.7',
#   '46821',
#   '26.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['194847',
#   '91.5',
#   '18089',
#   '8.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['9299',
#   '86.0',
#   '1509',
#   '14.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['189883',
#   '90.3',
#   '20298',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['2158741', '88.9', '268334', '11.1', '0', 'All Races', 'AR', '2021', '05'],
#  ['1524234',
#   '91.1',
#   '149522',
#   '8.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['330128',
#   '89.1',
#   '40192',
#   '10.9',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['173378',
#   '73.9',
#   '61348',
#   '26.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AR',
#   '2021',
#   '05'],
#  ['11671',
#   '83.0',
#   '2385',
#   '17.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['40145',
#   '89.2',
#   '4873',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['8509',
#   '80.2',
#   '2100',
#   '19.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['70676',
#   '89.9',
#   '7914',
#   '10.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['30088120', '91.9', '2640001', '8.1', '0', 'All Races', 'CA', '2021', '06'],
#  ['9898657',
#   '95.6',
#   '454709',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['1593081',
#   '93.5',
#   '110016',
#   '6.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['12399750',
#   '87.4',
#   '1782382',
#   '12.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CA',
#   '2021',
#   '06'],
#  ['80678',
#   '89.0',
#   '10006',
#   '11.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['4572897',
#   '95.7',
#   '206391',
#   '4.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['105713',
#   '91.7',
#   '9511',
#   '8.3',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['1437344',
#   '95.5',
#   '66986',
#   '4.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['4406138', '90.7', '452402', '9.3', '0', 'All Races', 'CO', '2021', '08'],
#  ['2908433',
#   '93.6',
#   '200326',
#   '6.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['175626',
#   '90.7',
#   '17950',
#   '9.3',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['964105',
#   '82.3',
#   '206845',
#   '17.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CO',
#   '2021',
#   '08'],
#  ['18349',
#   '86.5',
#   '2872',
#   '13.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['156586',
#   '93.1',
#   '11583',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['6631',
#   '90.0',
#   '740',
#   '10.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['176408',
#   '93.6',
#   '12086',
#   '6.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['2702690', '94.0', '172986', '6.0', '0', 'All Races', 'CT', '2021', '09'],
#  ['1681248',
#   '96.3',
#   '65216',
#   '3.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['288295',
#   '93.4',
#   '20377',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['500962',
#   '86.8',
#   '76223',
#   '13.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CT',
#   '2021',
#   '09'],
#  ['4306',
#   '93.3',
#   '307',
#   '6.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['143851',
#   '95.3',
#   '7103',
#   '4.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['959',
#   '93.9',
#   '62',
#   '6.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['83069',
#   '95.7',
#   '3698',
#   '4.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['724470', '93.1', '53437', '6.9', '0', 'All Races', 'DE', '2021', '10'],
#  ['415729',
#   '94.6',
#   '23781',
#   '5.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['165228',
#   '93.6',
#   '11286',
#   '6.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['78514',
#   '84.3',
#   '14608',
#   '15.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DE',
#   '2021',
#   '10'],
#  ['1408',
#   '91.0',
#   '140',
#   '9.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['32865',
#   '94.9',
#   '1754',
#   '5.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['251',
#   '89.6',
#   '29',
#   '10.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['30475',
#   '94.3',
#   '1839',
#   '5.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['528101', '96.3', '20443', '3.7', '0', 'All Races', 'DC', '2021', '11'],
#  ['200355',
#   '97.8',
#   '4555',
#   '2.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['218255',
#   '95.9',
#   '9390',
#   '4.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['64529',
#   '92.7',
#   '5110',
#   '7.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DC',
#   '2021',
#   '11'],
#  ['680',
#   '94.4',
#   '40',
#   '5.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['23947',
#   '97.0',
#   '728',
#   '3.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['225',
#   '96.6',
#   '8',
#   '3.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['20110',
#   '97.0',
#   '612',
#   '3.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['14254979', '84.9', '2534999', '15.1', '0', 'All Races', 'FL', '2021', '12'],
#  ['7001974',
#   '87.5',
#   '999603',
#   '12.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['2293682',
#   '84.5',
#   '421800',
#   '15.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['4032284',
#   '80.3',
#   '986549',
#   '19.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'FL',
#   '2021',
#   '12'],
#  ['24540',
#   '79.6',
#   '6274',
#   '20.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['456376',
#   '89.2',
#   '55272',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['9545',
#   '83.8',
#   '1839',
#   '16.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['436578',
#   '87.3',
#   '63662',
#   '12.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['7569926', '85.2', '1311686', '14.8', '0', 'All Races', 'GA', '2021', '13'],
#  ['3827292',
#   '88.2',
#   '509630',
#   '11.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['2392964',
#   '85.2',
#   '415326',
#   '14.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['718568',
#   '70.0',
#   '308410',
#   '30.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'GA',
#   '2021',
#   '13'],
#  ['11442',
#   '80.3',
#   '2809',
#   '19.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['366624',
#   '89.6',
#   '42596',
#   '10.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['5221',
#   '82.1',
#   '1135',
#   '17.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['247815',
#   '88.6',
#   '31780',
#   '11.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['1159751', '95.6', '53490', '4.4', '0', 'All Races', 'HI', '2021', '15'],
#  ['208257',
#   '95.7',
#   '9249',
#   '4.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['21213',
#   '95.4',
#   '1028',
#   '4.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['136165',
#   '92.9',
#   '10399',
#   '7.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'HI',
#   '2021',
#   '15'],
#  ['1526',
#   '93.7',
#   '102',
#   '6.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['340585',
#   '96.3',
#   '12980',
#   '3.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['97361',
#   '93.2',
#   '7112',
#   '6.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['354644',
#   '96.6',
#   '12620',
#   '3.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['1403972', '89.5', '163948', '10.5', '0', 'All Races', 'ID', '2021', '16'],
#  ['1128221',
#   '91.6',
#   '103267',
#   '8.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['10872',
#   '87.4',
#   '1565',
#   '12.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['184280',
#   '79.1',
#   '48787',
#   '20.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ID',
#   '2021',
#   '16'],
#  ['9753',
#   '82.0',
#   '2147',
#   '18.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['21430',
#   '90.1',
#   '2366',
#   '9.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['2442',
#   '84.9',
#   '435',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['46974',
#   '89.7',
#   '5381',
#   '10.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['9477028', '91.8', '845089', '8.2', '0', 'All Races', 'IL', '2021', '17'],
#  ['5599607',
#   '94.7',
#   '314195',
#   '5.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['1282220',
#   '91.2',
#   '124300',
#   '8.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['1733966',
#   '83.2',
#   '348972',
#   '16.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IL',
#   '2021',
#   '17'],
#  ['9889',
#   '89.3',
#   '1184',
#   '10.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['577415',
#   '93.5',
#   '40182',
#   '6.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['2629',
#   '90.5',
#   '276',
#   '9.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['271302',
#   '94.4',
#   '15980',
#   '5.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['5051991', '91.1', '494028', '8.9', '0', 'All Races', 'IN', '2021', '18'],
#  ['3846012',
#   '92.1',
#   '329342',
#   '7.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['486172',
#   '89.9',
#   '54376',
#   '10.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['402927',
#   '83.3',
#   '80777',
#   '16.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IN',
#   '2021',
#   '18'],
#  ['7386',
#   '85.4',
#   '1267',
#   '14.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['143268',
#   '91.5',
#   '13343',
#   '8.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['2009',
#   '87.5',
#   '287',
#   '12.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['164217',
#   '91.8',
#   '14636',
#   '8.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['2418667', '94.2', '148100', '5.8', '0', 'All Races', 'IA', '2021', '19'],
#  ['1993828',
#   '95.2',
#   '99996',
#   '4.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['102698',
#   '92.4',
#   '8401',
#   '7.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['171504',
#   '85.5',
#   '29156',
#   '14.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IA',
#   '2021',
#   '19'],
#  ['5214',
#   '89.4',
#   '615',
#   '10.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['69553',
#   '92.9',
#   '5277',
#   '7.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['4248',
#   '89.5',
#   '499',
#   '10.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['71622',
#   '94.5',
#   '4156',
#   '5.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['2136120', '89.1', '260427', '10.9', '0', 'All Races', 'KS', '2021', '20'],
#  ['1573464',
#   '91.6',
#   '144167',
#   '8.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['114359',
#   '85.9',
#   '18741',
#   '14.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['271305',
#   '78.4',
#   '74707',
#   '21.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KS',
#   '2021',
#   '20'],
#  ['11223',
#   '81.1',
#   '2623',
#   '18.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['70882',
#   '90.5',
#   '7406',
#   '9.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['2249',
#   '85.0',
#   '396',
#   '15.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['92638',
#   '88.2',
#   '12387',
#   '11.8',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['3397006', '93.2', '246692', '6.8', '0', 'All Races', 'KY', '2021', '21'],
#  ['2810916',
#   '94.1',
#   '176155',
#   '5.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['272640',
#   '91.8',
#   '24482',
#   '8.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['139490',
#   '80.5',
#   '33722',
#   '19.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KY',
#   '2021',
#   '21'],
#  ['4283',
#   '88.7',
#   '543',
#   '11.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['60425',
#   '93.0',
#   '4548',
#   '7.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['2566',
#   '89.3',
#   '308',
#   '10.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['106686',
#   '93.9',
#   '6934',
#   '6.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['3371196', '90.8', '339532', '9.2', '0', 'All Races', 'LA', '2021', '22'],
#  ['1956008',
#   '92.6',
#   '156609',
#   '7.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['1078618',
#   '91.0',
#   '106607',
#   '9.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['170847',
#   '74.2',
#   '59253',
#   '25.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'LA',
#   '2021',
#   '22'],
#  ['15130',
#   '83.8',
#   '2935',
#   '16.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['63522',
#   '90.5',
#   '6634',
#   '9.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['1228',
#   '86.9',
#   '185',
#   '13.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['85843',
#   '92.2',
#   '7309',
#   '7.8',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['977273', '92.7', '77458', '7.3', '0', 'All Races', 'ME', '2021', '23'],
#  ['891365',
#   '92.9',
#   '67840',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['18598',
#   '91.2',
#   '1791',
#   '8.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['20485',
#   '84.1',
#   '3860',
#   '15.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ME',
#   '2021',
#   '23'],
#  ['4538',
#   '88.8',
#   '573',
#   '11.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['13990',
#   '92.8',
#   '1090',
#   '7.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['323',
#   '90.5',
#   '34',
#   '9.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['27974',
#   '92.5',
#   '2270',
#   '7.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['4664762', '93.0', '349910', '7.0', '0', 'All Races', 'MD', '2021', '24'],
#  ['2240688',
#   '96.0',
#   '92888',
#   '4.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['1389705',
#   '93.5',
#   '96140',
#   '6.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['504514',
#   '79.6',
#   '129598',
#   '20.4',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MD',
#   '2021',
#   '24'],
#  ['7483',
#   '90.7',
#   '771',
#   '9.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['323314',
#   '94.4',
#   '19254',
#   '5.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['2170',
#   '91.6',
#   '199',
#   '8.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['196888',
#   '94.7',
#   '11060',
#   '5.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['5420689', '97.1', '162727', '2.9', '0', 'All Races', 'MA', '2021', '25'],
#  ['3645325',
#   '97.8',
#   '83829',
#   '2.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['408167',
#   '96.0',
#   '16988',
#   '4.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['766047',
#   '94.2',
#   '47076',
#   '5.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MA',
#   '2021',
#   '25'],
#  ['6799',
#   '96.0',
#   '284',
#   '4.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['421881',
#   '97.5',
#   '10715',
#   '2.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['2336',
#   '96.5',
#   '85',
#   '3.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['170134',
#   '97.8',
#   '3750',
#   '2.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['7585839', '94.0', '486048', '6.0', '0', 'All Races', 'MI', '2021', '26'],
#  ['5511237',
#   '94.7',
#   '310872',
#   '5.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['1019264',
#   '92.9',
#   '78320',
#   '7.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['455469',
#   '88.5',
#   '59297',
#   '11.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MI',
#   '2021',
#   '26'],
#  ['29514',
#   '87.3',
#   '4296',
#   '12.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['275699',
#   '95.2',
#   '13764',
#   '4.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['2018',
#   '91.4',
#   '191',
#   '8.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['292638',
#   '93.8',
#   '19308',
#   '6.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['4425088', '94.7', '247589', '5.3', '0', 'All Races', 'MN', '2021', '27'],
#  ['3368712',
#   '95.8',
#   '147840',
#   '4.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['332436',
#   '93.4',
#   '23374',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['265823',
#   '85.2',
#   '46248',
#   '14.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MN',
#   '2021',
#   '27'],
#  ['31608',
#   '85.7',
#   '5274',
#   '14.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['253156',
#   '94.6',
#   '14402',
#   '5.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['2579',
#   '92.1',
#   '221',
#   '7.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['170774',
#   '94.3',
#   '10230',
#   '5.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['2006272', '85.7', '335624', '14.3', '0', 'All Races', 'MS', '2021', '28'],
#  ['1122985',
#   '87.5',
#   '160152',
#   '12.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['748141',
#   '84.6',
#   '135690',
#   '15.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['63694',
#   '70.2',
#   '27043',
#   '29.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MS',
#   '2021',
#   '28'],
#  ['7207',
#   '76.6',
#   '2206',
#   '23.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['22962',
#   '85.1',
#   '4024',
#   '14.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['680',
#   '78.9',
#   '182',
#   '21.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['40603',
#   '86.5',
#   '6327',
#   '13.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['4403004', '88.6', '564179', '11.4', '0', 'All Races', 'MO', '2021', '29'],
#  ['3428434',
#   '89.8',
#   '389830',
#   '10.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['489170',
#   '86.2',
#   '78046',
#   '13.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['203851',
#   '77.8',
#   '58264',
#   '22.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MO',
#   '2021',
#   '29'],
#  ['12376',
#   '78.9',
#   '3302',
#   '21.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['103480',
#   '90.3',
#   '11116',
#   '9.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['6389',
#   '83.4',
#   '1271',
#   '16.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['159304',
#   '87.7',
#   '22350',
#   '12.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['773064', '89.5', '90685', '10.5', '0', 'All Races', 'MT', '2021', '30'],
#  ['660544',
#   '90.9',
#   '66058',
#   '9.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['4374',
#   '86.0',
#   '715',
#   '14.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['35205',
#   '80.8',
#   '8387',
#   '19.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MT',
#   '2021',
#   '30'],
#  ['32060',
#   '75.4',
#   '10464',
#   '24.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['7940',
#   '88.8',
#   '998',
#   '11.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['539',
#   '84.5',
#   '99',
#   '15.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['32402',
#   '89.1',
#   '3964',
#   '10.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['1470454', '91.5', '135758', '8.5', '0', 'All Races', 'NE', '2021', '31'],
#  ['1121550',
#   '93.8',
#   '74289',
#   '6.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['72859',
#   '89.9',
#   '8148',
#   '10.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['175541',
#   '80.0',
#   '43857',
#   '20.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NE',
#   '2021',
#   '31'],
#  ['8647',
#   '84.7',
#   '1558',
#   '15.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['42399',
#   '91.8',
#   '3798',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['973',
#   '88.4',
#   '128',
#   '11.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['48485',
#   '92.4',
#   '3980',
#   '7.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['2245764', '86.2', '358374', '13.8', '0', 'All Races', 'NV', '2021', '32'],
#  ['995648',
#   '90.8',
#   '100989',
#   '9.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['215839',
#   '87.9',
#   '29687',
#   '12.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['679955',
#   '78.8',
#   '182966',
#   '21.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NV',
#   '2021',
#   '32'],
#  ['12666',
#   '80.9',
#   '2986',
#   '19.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['187680',
#   '89.2',
#   '22775',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['14843',
#   '83.8',
#   '2877',
#   '16.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['139133',
#   '89.6',
#   '16094',
#   '10.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['1026504', '93.7', '69294', '6.3', '0', 'All Races', 'NH', '2021', '33'],
#  ['900220',
#   '94.2',
#   '55072',
#   '5.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['16528',
#   '92.0',
#   '1437',
#   '8.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['47581',
#   '85.2',
#   '8249',
#   '14.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NH',
#   '2021',
#   '33'],
#  ['1407',
#   '90.2',
#   '153',
#   '9.8',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['33706',
#   '93.1',
#   '2500',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['295',
#   '90.2',
#   '32',
#   '9.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['26767',
#   '93.5',
#   '1851',
#   '6.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['6916752', '91.7', '622957', '8.3', '0', 'All Races', 'NJ', '2021', '34'],
#  ['3638761',
#   '95.6',
#   '168178',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['878959',
#   '91.6',
#   '80508',
#   '8.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['1459381',
#   '81.8',
#   '324230',
#   '18.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NJ',
#   '2021',
#   '34'],
#  ['7344',
#   '91.1',
#   '716',
#   '8.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['744784',
#   '95.0',
#   '38858',
#   '5.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['2402',
#   '91.8',
#   '214',
#   '8.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['185121',
#   '94.8',
#   '10253',
#   '5.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['1441740', '87.4', '207637', '12.6', '0', 'All Races', 'NM', '2021', '35'],
#  ['488791',
#   '93.3',
#   '35362',
#   '6.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['28336',
#   '89.6',
#   '3275',
#   '10.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['768417',
#   '84.8',
#   '138010',
#   '15.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NM',
#   '2021',
#   '35'],
#  ['91276',
#   '78.7',
#   '24702',
#   '21.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['25555',
#   '91.8',
#   '2297',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['928',
#   '87.6',
#   '131',
#   '12.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['38437',
#   '90.9',
#   '3860',
#   '9.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['14935162', '93.9', '974408', '6.1', '0', 'All Races', 'NY', '2021', '36'],
#  ['7977617',
#   '96.0',
#   '330086',
#   '4.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['2088404',
#   '93.4',
#   '148380',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['3000461',
#   '88.8',
#   '377637',
#   '11.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NY',
#   '2021',
#   '36'],
#  ['31291',
#   '91.0',
#   '3094',
#   '9.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['1370809',
#   '93.8',
#   '91181',
#   '6.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['6808',
#   '92.3',
#   '569',
#   '7.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['459772',
#   '95.1',
#   '23461',
#   '4.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['7418267', '87.5', '1056777', '12.5', '0', 'All Races', 'NC', '2021', '37'],
#  ['4554632',
#   '90.6',
#   '473106',
#   '9.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['1551071',
#   '87.4',
#   '223049',
#   '12.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['718260',
#   '71.3',
#   '289577',
#   '28.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NC',
#   '2021',
#   '37'],
#  ['55086',
#   '78.9',
#   '14754',
#   '21.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['274809',
#   '91.7',
#   '24873',
#   '8.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['5156',
#   '84.9',
#   '915',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['259253',
#   '89.5',
#   '30503',
#   '10.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['570425', '90.8', '57728', '9.2', '0', 'All Races', 'ND', '2021', '38'],
#  ['473921',
#   '92.4',
#   '39016',
#   '7.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['19895',
#   '86.0',
#   '3249',
#   '14.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['25954',
#   '79.8',
#   '6557',
#   '20.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ND',
#   '2021',
#   '38'],
#  ['20557',
#   '78.3',
#   '5699',
#   '21.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['9954',
#   '90.1',
#   '1097',
#   '9.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['422',
#   '85.1',
#   '74',
#   '14.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['19722',
#   '90.6',
#   '2036',
#   '9.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['8721356', '92.2', '742266', '7.8', '0', 'All Races', 'OH', '2021', '39'],
#  ['6659323',
#   '92.9',
#   '505357',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['1088946',
#   '90.6',
#   '112354',
#   '9.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['388594',
#   '83.7',
#   '75457',
#   '16.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OH',
#   '2021',
#   '39'],
#  ['10830',
#   '86.8',
#   '1646',
#   '13.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['242225',
#   '91.8',
#   '21636',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['3918',
#   '88.7',
#   '501',
#   '11.3',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['327520',
#   '92.8',
#   '25315',
#   '7.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['2702249', '83.1', '547685', '16.9', '0', 'All Races', 'OK', '2021', '40'],
#  ['1715189',
#   '87.1',
#   '253789',
#   '12.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['193873',
#   '83.4',
#   '38451',
#   '16.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['316392',
#   '72.9',
#   '117803',
#   '27.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OK',
#   '2021',
#   '40'],
#  ['150052',
#   '67.0',
#   '73991',
#   '33.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['70220',
#   '86.6',
#   '10841',
#   '13.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['5310',
#   '76.8',
#   '1607',
#   '23.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['251213',
#   '83.1',
#   '51203',
#   '16.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['3175341', '92.6', '252038', '7.4', '0', 'All Races', 'OR', '2021', '41'],
#  ['2255995',
#   '94.0',
#   '144458',
#   '6.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['63984',
#   '92.5',
#   '5210',
#   '7.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['476587',
#   '86.0',
#   '77767',
#   '14.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OR',
#   '2021',
#   '41'],
#  ['23894',
#   '89.5',
#   '2812',
#   '10.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['161478',
#   '94.7',
#   '9074',
#   '5.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['13381',
#   '90.8',
#   '1356',
#   '9.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['180022',
#   '94.1',
#   '11361',
#   '5.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['9510210', '93.3', '681400', '6.7', '0', 'All Races', 'PA', '2021', '42'],
#  ['6937761',
#   '94.3',
#   '422450',
#   '5.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['1027525',
#   '92.8',
#   '79714',
#   '7.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['851643',
#   '86.4',
#   '133800',
#   '13.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'PA',
#   '2021',
#   '42'],
#  ['9367',
#   '90.1',
#   '1027',
#   '9.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['392336',
#   '93.5',
#   '27480',
#   '6.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['2926',
#   '91.6',
#   '267',
#   '8.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['288652',
#   '94.5',
#   '16662',
#   '5.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['823704', '95.1', '42429', '4.9', '0', 'All Races', 'RI', '2021', '44'],
#  ['554199',
#   '96.4',
#   '20522',
#   '3.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['52516',
#   '95.2',
#   '2630',
#   '4.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['154047',
#   '90.2',
#   '16727',
#   '9.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'RI',
#   '2021',
#   '44'],
#  ['2503',
#   '94.0',
#   '159',
#   '6.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['30378',
#   '95.9',
#   '1302',
#   '4.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['510',
#   '95.0',
#   '27',
#   '5.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['29551',
#   '96.5',
#   '1062',
#   '3.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['3583330', '87.7', '500507', '12.3', '0', 'All Races', 'SC', '2021', '45'],
#  ['2247878',
#   '89.9',
#   '253078',
#   '10.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['924072',
#   '87.2',
#   '135771',
#   '12.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['218444',
#   '72.0',
#   '84783',
#   '28.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SC',
#   '2021',
#   '45'],
#  ['8853',
#   '79.6',
#   '2273',
#   '20.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['71169',
#   '87.5',
#   '10199',
#   '12.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['2089',
#   '82.6',
#   '439',
#   '17.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['110825',
#   '88.8',
#   '13964',
#   '11.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['626412', '88.5', '81086', '11.5', '0', 'All Races', 'SD', '2021', '46'],
#  ['512586',
#   '91.3',
#   '48748',
#   '8.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['15285',
#   '83.5',
#   '3019',
#   '16.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['30224',
#   '78.8',
#   '8117',
#   '21.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SD',
#   '2021',
#   '46'],
#  ['33200',
#   '67.3',
#   '16158',
#   '32.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['11446',
#   '87.5',
#   '1630',
#   '12.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['402',
#   '82.0',
#   '88',
#   '18.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['23269',
#   '87.5',
#   '3326',
#   '12.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['4978730', '88.1', '670735', '11.9', '0', 'All Races', 'TN', '2021', '47'],
#  ['3614551',
#   '90.0',
#   '402631',
#   '10.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['811715',
#   '87.0',
#   '120878',
#   '13.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['282712',
#   '70.9',
#   '116100',
#   '29.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TN',
#   '2021',
#   '47'],
#  ['9002',
#   '81.5',
#   '2047',
#   '18.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['104137',
#   '89.7',
#   '11947',
#   '10.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['2657',
#   '83.9',
#   '511',
#   '16.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['153956',
#   '90.3',
#   '16621',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['19930607', '79.7', '5082397', '20.3', '0', 'All Races', 'TX', '2021', '48'],
#  ['8187256',
#   '87.8',
#   '1139837',
#   '12.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['2463370',
#   '82.9',
#   '506512',
#   '17.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['7491457',
#   '70.0',
#   '3206096',
#   '30.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TX',
#   '2021',
#   '48'],
#  ['44120',
#   '77.5',
#   '12827',
#   '22.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['1192404',
#   '89.9',
#   '133689',
#   '10.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['18266',
#   '80.8',
#   '4353',
#   '19.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['533734',
#   '87.1',
#   '79083',
#   '12.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['2622757', '89.9', '295109', '10.1', '0', 'All Races', 'UT', '2021', '49'],
#  ['2046111',
#   '92.9',
#   '156459',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['29736',
#   '86.8',
#   '4505',
#   '13.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['349468',
#   '76.1',
#   '109545',
#   '23.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'UT',
#   '2021',
#   '49'],
#  ['15988',
#   '80.6',
#   '3842',
#   '19.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['65837',
#   '90.6',
#   '6867',
#   '9.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['25609',
#   '85.9',
#   '4220',
#   '14.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['90008',
#   '90.3',
#   '9671',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['472219', '95.5', '22255', '4.5', '0', 'All Races', 'VT', '2021', '50'],
#  ['428845',
#   '95.6',
#   '19559',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['6713',
#   '94.6',
#   '386',
#   '5.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['11113',
#   '90.2',
#   '1205',
#   '9.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VT',
#   '2021',
#   '50'],
#  ['1011',
#   '93.4',
#   '72',
#   '6.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['10185',
#   '95.7',
#   '457',
#   '4.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['123',
#   '96.1',
#   '5',
#   '3.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['14229',
#   '96.1',
#   '571',
#   '3.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['6461548', '92.0', '559026', '8.0', '0', 'All Races', 'VA', '2021', '51'],
#  ['3834139',
#   '94.4',
#   '226940',
#   '5.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['1194156',
#   '92.2',
#   '100513',
#   '7.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['643518',
#   '79.0',
#   '170682',
#   '21.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VA',
#   '2021',
#   '51'],
#  ['11250',
#   '88.8',
#   '1424',
#   '11.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['475211',
#   '93.2',
#   '34529',
#   '6.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['4409',
#   '89.8',
#   '503',
#   '10.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['298865',
#   '92.4',
#   '24435',
#   '7.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['5944913', '92.4', '487958', '7.6', '0', 'All Races', 'WA', '2021', '53'],
#  ['3771465',
#   '94.5',
#   '220580',
#   '5.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['240385',
#   '91.4',
#   '22723',
#   '8.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['821017',
#   '83.0',
#   '168430',
#   '17.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WA',
#   '2021',
#   '53'],
#  ['48608',
#   '84.8',
#   '8744',
#   '15.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['601403',
#   '94.4',
#   '35859',
#   '5.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['42356',
#   '89.9',
#   '4758',
#   '10.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['419679',
#   '94.0',
#   '26864',
#   '6.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['1277435', '92.3', '105912', '7.7', '0', 'All Races', 'WV', '2021', '54'],
#  ['1158733',
#   '92.5',
#   '93387',
#   '7.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['42252',
#   '91.6',
#   '3880',
#   '8.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['24910',
#   '84.7',
#   '4490',
#   '15.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WV',
#   '2021',
#   '54'],
#  ['1667',
#   '87.9',
#   '230',
#   '12.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['11430',
#   '92.2',
#   '967',
#   '7.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['247',
#   '89.5',
#   '29',
#   '10.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['38196',
#   '92.9',
#   '2929',
#   '7.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['4422727', '93.5', '305258', '6.5', '0', 'All Races', 'WI', '2021', '55'],
#  ['3480098',
#   '94.8',
#   '190641',
#   '5.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['283440',
#   '91.8',
#   '25183',
#   '8.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['346945',
#   '84.1',
#   '65422',
#   '15.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WI',
#   '2021',
#   '55'],
#  ['27194',
#   '86.6',
#   '4201',
#   '13.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['150742',
#   '93.1',
#   '11104',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['1607',
#   '90.3',
#   '172',
#   '9.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['132701',
#   '94.0',
#   '8535',
#   '6.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['393704', '84.7', '71349', '15.3', '0', 'All Races', 'WY', '2021', '56'],
#  ['329233',
#   '87.0',
#   '49396',
#   '13.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['3750',
#   '80.5',
#   '911',
#   '19.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['39116',
#   '71.4',
#   '15696',
#   '28.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WY',
#   '2021',
#   '56'],
#  ['5559',
#   '70.8',
#   '2290',
#   '29.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['4033',
#   '83.5',
#   '795',
#   '16.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['248',
#   '79.0',
#   '66',
#   '21.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['11765',
#   '84.3',
#   '2195',
#   '15.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56']]

# %%
## create dataframe
df = pd.DataFrame(data[1:], columns =data[0])
df
# Out:
#       NIC_PT PCTIC_PT  NUI_PT PCTUI_PT RACECAT  \
# 0    3548525     88.3  469887     11.7       0
# 1    2293718     90.0  254385     10.0       1
# 2     921007     87.1  135939     12.9       2
# 3     163769     73.3   59615     26.7       3
# 4      13274     83.7    2587     16.3       4
# ..       ...      ...     ...      ...     ...
# 403    39116     71.4   15696     28.6       3
# 404     5559     70.8    2290     29.2       4
# 405     4033     83.5     795     16.5       5
# 406      248     79.0      66     21.0       6
# 407    11765     84.3    2195     15.7       7
#
#                                              RACE_DESC STABREV  time state
# 0                                            All Races      AL  2021    01
# 1                  White alone, not Hispanic or Latino      AL  2021    01
# 2    Black or African American alone, not Hispanic ...      AL  2021    01
# 3                        Hispanic or Latino (any race)      AL  2021    01
# 4    American Indian and Alaska Native alone, not H...      AL  2021    01
# ..                                                 ...     ...   ...   ...
# 403                      Hispanic or Latino (any race)      WY  2021    56
# 404  American Indian and Alaska Native alone, not H...      WY  2021    56
# 405                Asian alone, not Hispanic or Latino      WY  2021    56
# 406  Native Hawaiian and Other Pacific Islander alo...      WY  2021    56
# 407          Two or More Races, not Hispanic or Latino      WY  2021    56
#
# [408 rows x 9 columns]

# %%
## rename column headers with more meaning full headers
df.rename(columns = target_dict, inplace = True)
df
# Out:
#     total_insured pct_insured_est total_uninsured pct_uninsured_est  \
# 0         3548525            88.3          469887              11.7
# 1         2293718            90.0          254385              10.0
# 2          921007            87.1          135939              12.9
# 3          163769            73.3           59615              26.7
# 4           13274            83.7            2587              16.3
# ..            ...             ...             ...               ...
# 403         39116            71.4           15696              28.6
# 404          5559            70.8            2290              29.2
# 405          4033            83.5             795              16.5
# 406           248            79.0              66              21.0
# 407         11765            84.3            2195              15.7
#
#     race_category                                   race_description state  \
# 0               0                                          All Races    AL
# 1               1                White alone, not Hispanic or Latino    AL
# 2               2  Black or African American alone, not Hispanic ...    AL
# 3               3                      Hispanic or Latino (any race)    AL
# 4               4  American Indian and Alaska Native alone, not H...    AL
# ..            ...                                                ...   ...
# 403             3                      Hispanic or Latino (any race)    WY
# 404             4  American Indian and Alaska Native alone, not H...    WY
# 405             5                Asian alone, not Hispanic or Latino    WY
# 406             6  Native Hawaiian and Other Pacific Islander alo...    WY
# 407             7          Two or More Races, not Hispanic or Latino    WY
#
#      time state
# 0    2021    01
# 1    2021    01
# 2    2021    01
# 3    2021    01
# 4    2021    01
# ..    ...   ...
# 403  2021    56
# 404  2021    56
# 405  2021    56
# 406  2021    56
# 407  2021    56
#
# [408 rows x 9 columns]

# %% [markdown]
# ### 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
#
# - <a href="https://apps.fas.usda.gov/opendataweb/home">USDA APIs endpoints</a>
# - Get an <a href="https://apps.fas.usda.gov/opendataweb/home">API key</a>
#
# We want to create a dataframe with exports between 2020-2022 to all countries for the following commodities:
#
# 1. All Wheat
# 2. Oats
# 3. Cuts of Beef
# 4. Cuts of Pork

# %%
## find the parts to build your API call

# %%
## get commodities list
com_url = "https://apps.fas.usda.gov/OpenData/api/esr/commodities"

# %%
## we create a headers with your API key- use your own
headers = {
    'API_KEY': 'ADD-YOUR-KEY'
}

# %%
## now let's put into get requests
## we check the response status code
response  = requests.get(url = com_url, headers = poop)
response.status_code
all_commodities = response.json()
all_commodities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 ## now let's put into get requests
#       2 ## we check the response status code
# ----> 3 response  = requests.get(url = com_url, headers = poop)
#       4 response.status_code
#       5 all_commodities = response.json()
#
# NameError: name 'poop' is not defined

# %% [markdown]
# ### Get endpoint and test out on a single commodity

# %%
## your end point here
## trying on all wheat 

endpoint = "https://apps.fas.usda.gov/OpenData/api/esr/exports/commodityCode/107/allCountries/marketYear/2020"
# countries = "https://apps.fas.usda.gov/OpenData/api/esr/countries"

# %%
## now let's put into get requests
## we check the response status code
response = requests.get(url = endpoint, headers = headers)
response.status_code

# %%
## let's store our response into an object called data
response.json()

# %%
## convert that list of dicts into a dataframe called df
df = pd.DataFrame(response.json())
df

# %%
## Now iterate through all our target items

my_commodities = [
    {'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1},
    {'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
    {'commodityCode': 1701, 'commodityName': 'Beef',
  'unitId': 1},
    {'commodityCode': 1702, 'commodityName': 'Pork',
  'unitId': 1}]

my_commodities

# %%
my_commodities[0].get('commodityCode')

# %%
## endpoint templates
start_endpoint = "https://apps.fas.usda.gov/OpenData/api/esr/exports/commodityCode/"
end_endpoint = "/allCountries/marketYear/"

# %%
## iterate to get all the data
target_data = []
failed_endpoints = []
for commodity in my_commodities:
    target_code = commodity.get('commodityCode')
    ic(target_code)
    for year in range(2020,2023):
        ic(year)
        try:
            endpoint = f"{start_endpoint}{target_code}{end_endpoint}{year}"
            ##get response
            response = requests.get(url = endpoint, headers = headers)
            ## turn into dataframe
#             df = pd.DataFrame(response.json)
            target_data.append(pd.DataFrame(response.json()))
        except:
            print(f"Failed to retrieve data from {endpoint}...got status code {response.status_code}")
            failed_endpoints.append(endpoint)
print("done scraping API")

# %%
## call list
len(target_data)

# %%
## concat into single df
df = pd.concat(target_data).reset_index(drop = True)

# %%
## call df
df

# %%
## confirm we have all our target commodities
list(df["commodityCode"].unique())

# %% [markdown]
# ### 3. Federal Register – **tapping search terms.**
#
# We have decades of <a href="https://docs.google.com/spreadsheets/d/130WeumbMZjcoRP4D-1uJ7bM0aKBZzt4N/edit?usp=sharing&ouid=112307892189798608417&rtpof=true&sd=true">SBA Excel files</a> that detail loans given to small businesses to recover after climate disasters. The only information we have about the type of disasters are codes in one of the columns that look like:
#
# - CA-00279
# - IL-00051
# - NC-00099
# - CA-00288
# - LA-00079
#
# The <a href="https://www.federalregister.gov/">Federal Register</a> allows us to search for what these codes stand for. But we can't search for nearly a thousand such disaster codes. When we try to scrape the site, it warns us to use the API instead.
#
# Federal Register <a href="https://www.federalregister.gov/developers/documentation/api/v1#/Federal%20Register%20Documents/get_documents__format_">API documentation</a>

# %%
## find the end point

# %% [markdown]
# #### Test on single endpoint after figuring out how to build API call

# %%
## endpoint
endpoint = "https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]=CA-00279"

# %%
## get data
response = requests.get(endpoint)
data = response.json()
data
# Out:
# {'count': 5,
#  'description': 'Documents filed under agency docket CA-00279',
#  'total_pages': 1,
#  'results': [{'title': 'Presidential Declaration Amendment of a Major Disaster for the State of California',
#    'type': 'Notice',
#    'abstract': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 through 10/31/2017.',
#    'document_number': '2017-24850',
#    'html_url': 'https://www.federalregister.gov/documents/2017/11/16/2017-24850/presidential-declaration-amendment-of-a-major-disaster-for-the-state-of-california',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-11-16/pdf/2017-24850.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2017-24850.pdf?1510753574',
#    'publication_date': '2017-11-16',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 through 10/31/2017.'},
#   {'title': 'Presidential Declaration Amendment of a Major Disaster for the State of California',
#    'type': 'Notice',
#    'abstract': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.',
#    'document_number': '2017-22763',
#    'html_url': 'https://www.federalregister.gov/documents/2017/10/20/2017-22763/presidential-declaration-amendment-of-a-major-disaster-for-the-state-of-california',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-10-20/pdf/2017-22763.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2017-22763.pdf?1508417153',
#    'publication_date': '2017-10-20',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.'},
#   {'title': 'Presidential Declaration Amendment of a Major Disaster for the State of California',
#    'type': 'Notice',
#    'abstract': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.',
#    'document_number': '2017-22760',
#    'html_url': 'https://www.federalregister.gov/documents/2017/10/20/2017-22760/presidential-declaration-amendment-of-a-major-disaster-for-the-state-of-california',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-10-20/pdf/2017-22760.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2017-22760.pdf?1508417152',
#    'publication_date': '2017-10-20',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.'},
#   {'title': 'Presidential Declaration Amendment of a Major Disaster for the State of California',
#    'type': 'Notice',
#    'abstract': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.',
#    'document_number': '2017-22764',
#    'html_url': 'https://www.federalregister.gov/documents/2017/10/20/2017-22764/presidential-declaration-amendment-of-a-major-disaster-for-the-state-of-california',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-10-20/pdf/2017-22764.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2017-22764.pdf?1508417153',
#    'publication_date': '2017-10-20',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.'},
#   {'title': 'Presidential Declaration of a Major Disaster for the State of California',
#    'type': 'Notice',
#    'abstract': 'This is a Notice of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.',
#    'document_number': '2017-22673',
#    'html_url': 'https://www.federalregister.gov/documents/2017/10/19/2017-22673/presidential-declaration-of-a-major-disaster-for-the-state-of-california',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-10-19/pdf/2017-22673.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2017-22673.pdf?1508330741',
#    'publication_date': '2017-10-19',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is a Notice of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/2017. Incident: Wildfires. Incident Period: 10/08/2017 and continuing.'}]}

# %%
## type
type(data)
# Out:
# dict

# %%
## targeting incidents
data.get("results")[0].get("abstract")
# Out:
# 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 through 10/31/2017.'

# %% [markdown]
# ### Iterate through entire list of codes

# %%
## Normally will take from df as a list
## build disaster code list
disaster_codes = ["CA-00279","IL-00051", "NC-00099", "CA-00288", "LA-00079" ]

# %%
## provide base url
base_url = "https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]="

# %%
## iterate through all endpoints
incidents_list = []
broken_endpoints = []

for disaster_code in disaster_codes:
#     print(disaster_code)
    endpoint = base_url + disaster_code
#     print(endpoint)
    try:
        response = requests.get(endpoint)
        data = response.json()
        incident_text = data.get("results")[0].get("abstract")
#         print(incident_text)
        incidents_list.append({"disaster_code": disaster_code, "incident_text": incident_text})
    except:
        pass
incidents_list
# Out:
# [{'disaster_code': 'CA-00279',
#   'incident_text': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 through 10/31/2017.'},
#  {'disaster_code': 'IL-00051',
#   'incident_text': 'This is a notice of an Administrative declaration of a disaster for the State of Illinois dated 05/07/2018. Incident: Severe Storms and Flooding. Incident Period: 02/14/2018 through 03/04/2018.'},
#  {'disaster_code': 'NC-00099',
#   'incident_text': 'This is an amendment of the Presidential declaration of a major disaster for the State of North Carolina (FEMA-4393-DR), dated 09/14/2018. Incident: Hurricane Florence. Incident Period: 09/07/2018 through 09/29/2018.'},
#  {'disaster_code': 'CA-00288',
#   'incident_text': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4382-DR), dated 08/04/ 2018. Incident: Wildfires and High Winds. Incident Period: 07/23/2018 through 09/19/2018.'},
#  {'disaster_code': 'LA-00079',
#   'incident_text': 'This is a notice of an Administrative declaration of a disaster for the State of Louisiana dated 01/02/2018. Incident: Tropical Storm Harvey. Incident Period: 08/27/2017 through 09/10/2017.'}]

# %%
## call list
# Write to CSV file
# Extract the relevant information
rows = [(entry['disaster_code'], entry['incident_text'].split('Incident:')[1].split('Incident Period:')[0].strip()) for entry in incidents_list]

# Create a DataFrame
df = pd.DataFrame(rows, columns=['disaster_code', 'incident_text'])

# Write to CSV file using df.to_csv
csv_filename = 'disaster_data_pandas.csv'
df.to_csv(csv_filename, index=False)

print(f'CSV file "{csv_filename}" created successfully.')
# Out:
# CSV file "disaster_data_pandas.csv" created successfully.

# %% [markdown]
# ### 4. Energy Information Administration – **dealing with pagination.**
#
# From the <a href="https://www.eia.gov/">Energy Information Administration</a>, we want to compile electricity generation by type of fuel and region for about 5 days hourly.
#
# We will encounter a limit on the number of items per API call.
#
# Find our API endpoint first.

# %%
## your target endpoint
endpoint = "https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN"

# %%
## get response
response = requests.get(endpoint)
data = response.json()
data
# Out:
# {'response': {'warnings': [{'warning': 'incomplete return',
#     'description': 'The API can only return 5000 rows in JSON format.  Please consider constraining your request with facet, start, or end, or using offset to paginate results.'}],
#   'total': 56260,
#   'dateFormat': 'YYYY-MM-DD"T"HH24',
#   'frequency': 'hourly',
#   'data': [{'period': '2023-01-07T00',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 3266,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SOCO',
#     'respondent-name': 'Southern Company Services, Inc. - Trans',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ERCO',
#     'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 5091,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SEC',
#     'respondent-name': 'Seminole Electric Cooperative',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 312,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 13142,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CPLW',
#     'respondent-name': 'Duke Energy Progress West',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 8,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CPLE',
#     'respondent-name': 'Duke Energy Progress East',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 64,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 236,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AVRN',
#     'respondent-name': 'Avangrid Renewables, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 525,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSCO',
#     'respondent-name': 'Public Service Company of Colorado',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 20,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AVRN',
#     'respondent-name': 'Avangrid Renewables, LLC',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NY',
#     'respondent-name': 'New York',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NWMT',
#     'respondent-name': 'NorthWestern Corporation',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 147,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AZPS',
#     'respondent-name': 'Arizona Public Service Company',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 51,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NE',
#     'respondent-name': 'New England',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 3,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GWA',
#     'respondent-name': 'NaturEner Power Watch, LLC',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 167,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 15692,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BPAT',
#     'respondent-name': 'Bonneville Power Administration',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 114,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IID',
#     'respondent-name': 'Imperial Irrigation District',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SW',
#     'respondent-name': 'Southwest',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 263,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NWMT',
#     'respondent-name': 'NorthWestern Corporation',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 829,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AVA',
#     'respondent-name': 'Avista Corporation',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 214,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GRID',
#     'respondent-name': 'Gridforce Energy Management, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1127,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LDWP',
#     'respondent-name': 'Los Angeles Department of Water and Power',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 175,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACE',
#     'respondent-name': 'PacifiCorp East',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 3698,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAR',
#     'respondent-name': 'Carolinas',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1821,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CISO',
#     'respondent-name': 'California Independent System Operator',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 394,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WALC',
#     'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 240,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'HST',
#     'respondent-name': 'City of Homestead',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WACM',
#     'respondent-name': 'Western Area Power Administration - Rocky Mountain Region',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 3095,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AECI',
#     'respondent-name': 'Associated Electric Cooperative, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 2169,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 28,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GCPD',
#     'respondent-name': 'Public Utility District No. 2 of Grant County, Washington',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1026,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IID',
#     'respondent-name': 'Imperial Irrigation District',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 244,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 8251,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 283,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 6358,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 32713,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AECI',
#     'respondent-name': 'Associated Electric Cooperative, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1214,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 8251,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MISO',
#     'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 2431,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 30,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BPAT',
#     'respondent-name': 'Bonneville Power Administration',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 7832,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'DUK',
#     'respondent-name': 'Duke Energy Carolinas',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 2333,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEPC',
#     'respondent-name': 'Tucson Electric Power',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 105,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 7739,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GVL',
#     'respondent-name': 'Gainesville Regional Utilities',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 91,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEX',
#     'respondent-name': 'Texas',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 21,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AZPS',
#     'respondent-name': 'Arizona Public Service Company',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 614,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 674,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FLA',
#     'respondent-name': 'Florida',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 3877,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BPAT',
#     'respondent-name': 'Bonneville Power Administration',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 13,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SOCO',
#     'respondent-name': 'Southern Company Services, Inc. - Trans',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IPCO',
#     'respondent-name': 'Idaho Power Company',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 47,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AZPS',
#     'respondent-name': 'Arizona Public Service Company',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 865,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CPLW',
#     'respondent-name': 'Duke Energy Progress West',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 79,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 82,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 801,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AVA',
#     'respondent-name': 'Avista Corporation',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 400,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 463,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MISO',
#     'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 34271,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEC',
#     'respondent-name': 'Tampa Electric Company',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 3994,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 14,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 1004,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WALC',
#     'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 97,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ERCO',
#     'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 5111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 2260,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACE',
#     'respondent-name': 'PacifiCorp East',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 46,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 15692,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BANC',
#     'respondent-name': 'Balancing Authority of Northern California',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 16,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSCO',
#     'respondent-name': 'Public Service Company of Colorado',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 73,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ERCO',
#     'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 13794,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AZPS',
#     'respondent-name': 'Arizona Public Service Company',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 33,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PNM',
#     'respondent-name': 'Public Service Company of New Mexico',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 396,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SW',
#     'respondent-name': 'Southwest',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 38,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEPC',
#     'respondent-name': 'Tucson Electric Power',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 328,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'JEA',
#     'respondent-name': 'JEA',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 597,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MISO',
#     'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 672,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEPC',
#     'respondent-name': 'Tucson Electric Power',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 702,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PGE',
#     'respondent-name': 'Portland General Electric Company',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 247,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FPL',
#     'respondent-name': 'Florida Power & Light Co.',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 3399,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEX',
#     'respondent-name': 'Texas',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 901,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 2557,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SCL',
#     'respondent-name': 'Seattle City Light',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 691,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IID',
#     'respondent-name': 'Imperial Irrigation District',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 431,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PNM',
#     'respondent-name': 'Public Service Company of New Mexico',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1461,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WAUW',
#     'respondent-name': 'Western Area Power Administration - Upper Great Plains West',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 81,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CPLW',
#     'respondent-name': 'Duke Energy Progress West',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 184,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 144,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 2087,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IPCO',
#     'respondent-name': 'Idaho Power Company',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 491,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SOCO',
#     'respondent-name': 'Southern Company Services, Inc. - Trans',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 5858,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 4,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SW',
#     'respondent-name': 'Southwest',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 5060,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BANC',
#     'respondent-name': 'Balancing Authority of Northern California',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 702,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'YAD',
#     'respondent-name': 'Alcoa Power Generating, Inc. - Yadkin Division',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 174,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 1140,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BANC',
#     'respondent-name': 'Balancing Authority of Northern California',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 563,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 349,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 2791,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 1987,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 5858,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 10,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LGEE',
#     'respondent-name': 'Louisville Gas and Electric Company and Kentucky Utilities Company',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 16,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'DEAA',
#     'respondent-name': 'Arlington Valley, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': -3,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PGE',
#     'respondent-name': 'Portland General Electric Company',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 815,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 41,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NY',
#     'respondent-name': 'New York',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 7739,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEX',
#     'respondent-name': 'Texas',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 5111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'DOPD',
#     'respondent-name': 'PUD No. 1 of Douglas County',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 463,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 327,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CPLE',
#     'respondent-name': 'Duke Energy Progress East',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 2301,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PNM',
#     'respondent-name': 'Public Service Company of New Mexico',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FPC',
#     'respondent-name': 'Duke Energy Florida, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': -15,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NWMT',
#     'respondent-name': 'NorthWestern Corporation',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSCO',
#     'respondent-name': 'Public Service Company of Colorado',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 1548,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WACM',
#     'respondent-name': 'Western Area Power Administration - Rocky Mountain Region',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 12,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CISO',
#     'respondent-name': 'California Independent System Operator',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 5680,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GRID',
#     'respondent-name': 'Gridforce Energy Management, LLC',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 648,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 57,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SEC',
#     'respondent-name': 'Seminole Electric Cooperative',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 1111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FLA',
#     'respondent-name': 'Florida',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 18583,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CHPD',
#     'respondent-name': 'Public Utility District No. 1 of Chelan County',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SW',
#     'respondent-name': 'Southwest',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 240,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LGEE',
#     'respondent-name': 'Louisville Gas and Electric Company and Kentucky Utilities Company',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1034,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 45292,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SOCO',
#     'respondent-name': 'Southern Company Services, Inc. - Trans',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 84,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WACM',
#     'respondent-name': 'Western Area Power Administration - Rocky Mountain Region',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 227,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 126,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'IPCO',
#     'respondent-name': 'Idaho Power Company',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 32,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAR',
#     'respondent-name': 'Carolinas',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 1415,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 1987,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PGE',
#     'respondent-name': 'Portland General Electric Company',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACE',
#     'respondent-name': 'PacifiCorp East',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1500,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'GVL',
#     'respondent-name': 'Gainesville Regional Utilities',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 97,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1153,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SCEG',
#     'respondent-name': 'Dominion Energy South Carolina, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 480,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NY',
#     'respondent-name': 'New York',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 327,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 1160,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LGEE',
#     'respondent-name': 'Louisville Gas and Electric Company and Kentucky Utilities Company',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 68,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 2116,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1285,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 771,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 48,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 45292,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FPC',
#     'respondent-name': 'Duke Energy Florida, Inc.',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SOCO',
#     'respondent-name': 'Southern Company Services, Inc. - Trans',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 13757,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'AVRN',
#     'respondent-name': 'Avangrid Renewables, LLC',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 40,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEC',
#     'respondent-name': 'Tampa Electric Company',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 467,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'JEA',
#     'respondent-name': 'JEA',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 2,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 10899,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PGE',
#     'respondent-name': 'Portland General Electric Company',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 418,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 128,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BPAT',
#     'respondent-name': 'Bonneville Power Administration',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 165,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LDWP',
#     'respondent-name': 'Los Angeles Department of Water and Power',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 401,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACE',
#     'respondent-name': 'PacifiCorp East',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 193,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'HGMA',
#     'respondent-name': 'New Harquahala Generating Company, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': -3,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 11,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CISO',
#     'respondent-name': 'California Independent System Operator',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 662,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 3326,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 263,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 2087,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MISO',
#     'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 2100,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 17,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 2692,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': -1,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 672,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 5764,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 94138,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CAR',
#     'respondent-name': 'Carolinas',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 7147,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NE',
#     'respondent-name': 'New England',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1452,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CHPD',
#     'respondent-name': 'Public Utility District No. 1 of Chelan County',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 849,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1152,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSCO',
#     'respondent-name': 'Public Service Company of Colorado',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1473,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 42110,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LDWP',
#     'respondent-name': 'Los Angeles Department of Water and Power',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 500,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 9776,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': -1,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 482,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SCEG',
#     'respondent-name': 'Dominion Energy South Carolina, Inc.',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 995,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'BANC',
#     'respondent-name': 'Balancing Authority of Northern California',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 33,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1152,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 5897,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'LDWP',
#     'respondent-name': 'Los Angeles Department of Water and Power',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 513,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'DUK',
#     'respondent-name': 'Duke Energy Carolinas',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': -2,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 4008,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 13757,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 11599,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 4630,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'CISO',
#     'respondent-name': 'California Independent System Operator',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 9488,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'TAL',
#     'respondent-name': 'City of Tallahassee',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 372,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WACM',
#     'respondent-name': 'Western Area Power Administration - Rocky Mountain Region',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 627,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'FPL',
#     'respondent-name': 'Florida Power & Light Co.',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 2723,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NWMT',
#     'respondent-name': 'NorthWestern Corporation',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 392,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'WALC',
#     'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 33,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'DUK',
#     'respondent-name': 'Duke Energy Carolinas',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1309,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-07T00',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 3415,
#     'value-units': 'megawatthours'},
# ...
#     'respondent': 'TEN',
#     'respondent-name': 'Tennessee',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 2957,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 3631,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PACE',
#     'respondent-name': 'PacifiCorp East',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 560,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NWMT',
#     'respondent-name': 'NorthWestern Corporation',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 829,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MISO',
#     'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 32299,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1671,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SW',
#     'respondent-name': 'Southwest',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 33,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'ERCO',
#     'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 5111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'DUK',
#     'respondent-name': 'Duke Energy Carolinas',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 1299,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SC',
#     'respondent-name': 'South Carolina Public Service Authority',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 63,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NE',
#     'respondent-name': 'New England',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 3423,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'WAUW',
#     'respondent-name': 'Western Area Power Administration - Upper Great Plains West',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 78,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 5111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PGE',
#     'respondent-name': 'Portland General Electric Company',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CHPD',
#     'respondent-name': 'Public Utility District No. 1 of Chelan County',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 703,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 429,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PSEI',
#     'respondent-name': 'Puget Sound Energy, Inc.',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 4,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 4,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 736,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'WALC',
#     'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 211,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 584,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 991,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'IID',
#     'respondent-name': 'Imperial Irrigation District',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 428,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SCEG',
#     'respondent-name': 'Dominion Energy South Carolina, Inc.',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 247,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 170,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SCEG',
#     'respondent-name': 'Dominion Energy South Carolina, Inc.',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 979,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'TEC',
#     'respondent-name': 'Tampa Electric Company',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PACW',
#     'respondent-name': 'PacifiCorp West',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 87,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'TEX',
#     'respondent-name': 'Texas',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 70,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 1159,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'FMPP',
#     'respondent-name': 'Florida Municipal Power Pool',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 18,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SCEG',
#     'respondent-name': 'Dominion Energy South Carolina, Inc.',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 992,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 31113,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 5111,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': -368,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'JEA',
#     'respondent-name': 'JEA',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 11,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDW',
#     'respondent-name': 'Midwest',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1162,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CENT',
#     'respondent-name': 'Central',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 10821,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1417,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'ERCO',
#     'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 70,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CAL',
#     'respondent-name': 'California',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 852,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 94173,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': 15148,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NW',
#     'respondent-name': 'Northwest',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 8802,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'GRIF',
#     'respondent-name': 'Griffith Energy, LLC',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': -2,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'MIDA',
#     'respondent-name': 'Mid-Atlantic',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 32718,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CISO',
#     'respondent-name': 'California Independent System Operator',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1420,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 32,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CPLE',
#     'respondent-name': 'Duke Energy Progress East',
#     'fueltype': 'COL',
#     'type-name': 'Coal',
#     'value': -22,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'TVA',
#     'respondent-name': 'Tennessee Valley Authority',
#     'fueltype': 'WAT',
#     'type-name': 'Hydro',
#     'value': 1632,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'WWA',
#     'respondent-name': 'NaturEner Wind Watch, LLC',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 117,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'TEPC',
#     'respondent-name': 'Tucson Electric Power',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 299,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'ISNE',
#     'respondent-name': 'ISO New England',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 2,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'CPLE',
#     'respondent-name': 'Duke Energy Progress East',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 1756,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'OIL',
#     'type-name': 'Petroleum',
#     'value': 1074,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 170,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 2061,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NEVP',
#     'respondent-name': 'Nevada Power Company',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 1382,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'AVA',
#     'respondent-name': 'Avista Corporation',
#     'fueltype': 'OTH',
#     'type-name': 'Other',
#     'value': 123,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NYIS',
#     'respondent-name': 'New York Independent System Operator',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 389,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SWPP',
#     'respondent-name': 'Southwest Power Pool',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 5527,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SE',
#     'respondent-name': 'Southeast',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 0,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'SRP',
#     'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#     'fueltype': 'NUC',
#     'type-name': 'Nuclear',
#     'value': 4010,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PNM',
#     'respondent-name': 'Public Service Company of New Mexico',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1579,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'US48',
#     'respondent-name': 'United States Lower 48',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 169596,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'PJM',
#     'respondent-name': 'PJM Interconnection, LLC',
#     'fueltype': 'WND',
#     'type-name': 'Wind',
#     'value': 1326,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'GVL',
#     'respondent-name': 'Gainesville Regional Utilities',
#     'fueltype': 'NG',
#     'type-name': 'Natural gas',
#     'value': 79,
#     'value-units': 'megawatthours'},
#    {'period': '2023-01-06T22',
#     'respondent': 'NE',
#     'respondent-name': 'New England',
#     'fueltype': 'SUN',
#     'type-name': 'Solar',
#     'value': 2,
#     'value-units': 'megawatthours'},
#    ...],
#   'description': 'Hourly net generation by balancing authority and energy source.  \n    Source: Form EIA-930\n    Product: Hourly Electric Grid Monitor'},
#  'request': {'command': '/v2/electricity/rto/fuel-type-data/data/',
#   'params': {'frequency': 'hourly',
#    'data': ['value'],
#    'start': '2023-01-01T00',
#    'end': '2023-01-07T00',
#    'sort': [{'column': 'period', 'direction': 'desc'}],
#    'offset': 0,
#    'length': 5000,
#    'api_key': 'Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'}},
#  'apiVersion': '2.1.5',
#  'ExcelAddInVersion': '2.1.0'}

# %%
## import ceiling division from math

from math import ceil

# %%
## your target endpoint
endpoint = "https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset="
api_key= "&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN"

# %%
## total pages:
rows_per_page = 5000
total_rows = data.get("response").get("total")
total_pages = ceil(total_rows/rows_per_page)
total_pages
# Out:
# 12

# %%
## paginate our API calls
## for loop with pagination

all_data = []

for page in range(total_pages):
#     print(page)
    offset = page * rows_per_page
    api_url = f"{endpoint}{offset}{api_key}"
    ic(api_url)
    response = requests.get(api_url)
    data = response.json()
    all_data.append(data.get("response").get("data"))
# Out:
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=5000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=10000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=15000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=20000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=25000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=30000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=35000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=40000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=45000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=50000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'
# ic| api_url: 'https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/?frequency=hourly&data[0]=value&start=2023-01-01T00&end=2023-01-07T00&sort[0][column]=period&sort[0][direction]=desc&offset=55000&length=5000&api_key=Bo53FXqDefHvjNY97PmF3XYdfOap8hOaced0YFeN'

# %%
## call all data
all_data
# Out:
# [[{'period': '2023-01-07T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 17873,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AECI',
#    'respondent-name': 'Associated Electric Cooperative, Inc.',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 261,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2394,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 8095,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 956,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NE',
#    'respondent-name': 'New England',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 8095,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 367,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SEPA',
#    'respondent-name': 'Southeastern Power Administration',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 279,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NYIS',
#    'respondent-name': 'New York Independent System Operator',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 3594,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPC',
#    'respondent-name': 'Duke Energy Florida, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 4514,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 4347,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 1160,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDA',
#    'respondent-name': 'Mid-Atlantic',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1682,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 21,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVA',
#    'respondent-name': 'Avista Corporation',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 19,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACW',
#    'respondent-name': 'PacifiCorp West',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 11,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SC',
#    'respondent-name': 'South Carolina Public Service Authority',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': -1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 223,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 189551,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 14181,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 8,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WWA',
#    'respondent-name': 'NaturEner Wind Watch, LLC',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 147,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FLA',
#    'respondent-name': 'Florida',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 39,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 82,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 37810,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IPCO',
#    'respondent-name': 'Idaho Power Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 552,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 31958,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SW',
#    'respondent-name': 'Southwest',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 1845,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 32,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 3641,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 72,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NE',
#    'respondent-name': 'New England',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 3399,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GRID',
#    'respondent-name': 'Gridforce Energy Management, LLC',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 18,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1144,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PGE',
#    'respondent-name': 'Portland General Electric Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 163,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 9444,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 9776,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 889,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 36519,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SCEG',
#    'respondent-name': 'Dominion Energy South Carolina, Inc.',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 111,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 171,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SW',
#    'respondent-name': 'Southwest',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 4008,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GRIF',
#    'respondent-name': 'Griffith Energy, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': -3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 2087,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IPCO',
#    'respondent-name': 'Idaho Power Company',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 491,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 5858,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 4,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSEI',
#    'respondent-name': 'Puget Sound Energy, Inc.',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 28,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GCPD',
#    'respondent-name': 'Public Utility District No. 2 of Grant County, Washington',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1026,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IID',
#    'respondent-name': 'Imperial Irrigation District',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 244,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 3994,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1022,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TIDC',
#    'respondent-name': 'Turlock Irrigation District',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 55,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 652,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LGEE',
#    'respondent-name': 'Louisville Gas and Electric Company and Kentucky Utilities Company',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 2976,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NY',
#    'respondent-name': 'New York',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 3415,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GVL',
#    'respondent-name': 'Gainesville Regional Utilities',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WALC',
#    'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 523,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1682,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NY',
#    'respondent-name': 'New York',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 375,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2512,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WACM',
#    'respondent-name': 'Western Area Power Administration - Rocky Mountain Region',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 378,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1452,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1226,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WALC',
#    'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 97,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 5111,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 2260,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACE',
#    'respondent-name': 'PacifiCorp East',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 46,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 15692,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BANC',
#    'respondent-name': 'Balancing Authority of Northern California',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 16,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSCO',
#    'respondent-name': 'Public Service Company of Colorado',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 73,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 13794,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 33,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 396,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FMPP',
#    'respondent-name': 'Florida Municipal Power Pool',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SW',
#    'respondent-name': 'Southwest',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 38,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEPC',
#    'respondent-name': 'Tucson Electric Power',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 328,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'JEA',
#    'respondent-name': 'JEA',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 597,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 672,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SW',
#    'respondent-name': 'Southwest',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 5060,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BANC',
#    'respondent-name': 'Balancing Authority of Northern California',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 702,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'YAD',
#    'respondent-name': 'Alcoa Power Generating, Inc. - Yadkin Division',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 174,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SC',
#    'respondent-name': 'South Carolina Public Service Authority',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 1140,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BANC',
#    'respondent-name': 'Balancing Authority of Northern California',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 563,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 349,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2791,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 1987,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 5858,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 10,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LGEE',
#    'respondent-name': 'Louisville Gas and Electric Company and Kentucky Utilities Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 16,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'DEAA',
#    'respondent-name': 'Arlington Valley, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': -3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PGE',
#    'respondent-name': 'Portland General Electric Company',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 815,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACW',
#    'respondent-name': 'PacifiCorp West',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 41,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 79,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 82,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SC',
#    'respondent-name': 'South Carolina Public Service Authority',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 801,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVA',
#    'respondent-name': 'Avista Corporation',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 400,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FMPP',
#    'respondent-name': 'Florida Municipal Power Pool',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 463,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 34271,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEC',
#    'respondent-name': 'Tampa Electric Company',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 3994,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 14,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1004,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 10899,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PGE',
#    'respondent-name': 'Portland General Electric Company',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACW',
#    'respondent-name': 'PacifiCorp West',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 418,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FMPP',
#    'respondent-name': 'Florida Municipal Power Pool',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 128,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 165,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 401,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACE',
#    'respondent-name': 'PacifiCorp East',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 193,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'HGMA',
#    'respondent-name': 'New Harquahala Generating Company, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': -3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 11,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 662,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 3326,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 263,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 2087,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2100,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FMPP',
#    'respondent-name': 'Florida Municipal Power Pool',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 17,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 2692,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': -1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 672,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 5764,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 94138,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 7147,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NE',
#    'respondent-name': 'New England',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1452,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FMPP',
#    'respondent-name': 'Florida Municipal Power Pool',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CHPD',
#    'respondent-name': 'Public Utility District No. 1 of Chelan County',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 849,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 1152,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 21,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSEI',
#    'respondent-name': 'Puget Sound Energy, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 614,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 674,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FLA',
#    'respondent-name': 'Florida',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 3877,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 13,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IPCO',
#    'respondent-name': 'Idaho Power Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 47,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 865,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 8251,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 283,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAL',
#    'respondent-name': 'California',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 6358,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDA',
#    'respondent-name': 'Mid-Atlantic',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 32713,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AECI',
#    'respondent-name': 'Associated Electric Cooperative, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 1214,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 8251,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 2431,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 30,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 7832,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'DUK',
#    'respondent-name': 'Duke Energy Carolinas',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 2333,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEPC',
#    'respondent-name': 'Tucson Electric Power',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 105,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NYIS',
#    'respondent-name': 'New York Independent System Operator',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 7739,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GVL',
#    'respondent-name': 'Gainesville Regional Utilities',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 91,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 48,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDA',
#    'respondent-name': 'Mid-Atlantic',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 45292,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPC',
#    'respondent-name': 'Duke Energy Florida, Inc.',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 13757,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVRN',
#    'respondent-name': 'Avangrid Renewables, LLC',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SRP',
#    'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 40,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEC',
#    'respondent-name': 'Tampa Electric Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 467,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'JEA',
#    'respondent-name': 'JEA',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 2,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSCO',
#    'respondent-name': 'Public Service Company of Colorado',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 1473,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 42110,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 500,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 9776,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': -1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NEVP',
#    'respondent-name': 'Nevada Power Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 482,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SRP',
#    'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SCEG',
#    'respondent-name': 'Dominion Energy South Carolina, Inc.',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 995,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 13142,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 8,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 64,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SRP',
#    'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 236,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NY',
#    'respondent-name': 'New York',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 7739,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 5111,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'DOPD',
#    'respondent-name': 'PUD No. 1 of Douglas County',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 463,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NYIS',
#    'respondent-name': 'New York Independent System Operator',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 327,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 2301,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVRN',
#    'respondent-name': 'Avangrid Renewables, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 525,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSCO',
#    'respondent-name': 'Public Service Company of Colorado',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 20,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVRN',
#    'respondent-name': 'Avangrid Renewables, LLC',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NY',
#    'respondent-name': 'New York',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NWMT',
#    'respondent-name': 'NorthWestern Corporation',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 147,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSEI',
#    'respondent-name': 'Puget Sound Energy, Inc.',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 51,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NE',
#    'respondent-name': 'New England',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GWA',
#    'respondent-name': 'NaturEner Power Watch, LLC',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 167,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'MIDA',
#    'respondent-name': 'Mid-Atlantic',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 15692,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SOCO',
#    'respondent-name': 'Southern Company Services, Inc. - Trans',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 5091,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SEC',
#    'respondent-name': 'Seminole Electric Cooperative',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 312,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 114,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IID',
#    'respondent-name': 'Imperial Irrigation District',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SW',
#    'respondent-name': 'Southwest',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 263,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'NWMT',
#    'respondent-name': 'NorthWestern Corporation',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 829,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'AVA',
#    'respondent-name': 'Avista Corporation',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 214,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'GRID',
#    'respondent-name': 'Gridforce Energy Management, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 1127,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 175,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PACE',
#    'respondent-name': 'PacifiCorp East',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 3698,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1821,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 394,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WALC',
#    'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 240,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'HST',
#    'respondent-name': 'City of Homestead',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPC',
#    'respondent-name': 'Duke Energy Florida, Inc.',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 90,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'DUK',
#    'respondent-name': 'Duke Energy Carolinas',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 7384,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 38,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEPC',
#    'respondent-name': 'Tucson Electric Power',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 702,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PGE',
#    'respondent-name': 'Portland General Electric Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 247,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'ISNE',
#    'respondent-name': 'ISO New England',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 3399,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 901,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2557,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'SCL',
#    'respondent-name': 'Seattle City Light',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 691,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'IID',
#    'respondent-name': 'Imperial Irrigation District',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 431,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 1461,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'WAUW',
#    'respondent-name': 'Western Area Power Administration - Upper Great Plains West',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 81,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 184,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'PSEI',
#    'respondent-name': 'Puget Sound Energy, Inc.',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 144,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 17873,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-07T00',
#    'respondent': 'EPE',
#    'respondent-name': 'El Paso Electric Company',
# ...
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 8897,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MIDA',
#    'respondent-name': 'Mid-Atlantic',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 952,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 6834,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 66,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 5126,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TEC',
#    'respondent-name': 'Tampa Electric Company',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 1703,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TEX',
#    'respondent-name': 'Texas',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 431,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'IPCO',
#    'respondent-name': 'Idaho Power Company',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 57,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'JEA',
#    'respondent-name': 'JEA',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 182,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 6834,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 527,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'ERCO',
#    'respondent-name': 'Electric Reliability Council of Texas, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 13975,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 72,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'NYIS',
#    'respondent-name': 'New York Independent System Operator',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 3605,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PSCO',
#    'respondent-name': 'Public Service Company of Colorado',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 1719,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 1429,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CPLE',
#    'respondent-name': 'Duke Energy Progress East',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': -20,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 255,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SC',
#    'respondent-name': 'South Carolina Public Service Authority',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 483,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 7638,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 11813,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CPLW',
#    'respondent-name': 'Duke Energy Progress West',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 8,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TEC',
#    'respondent-name': 'Tampa Electric Company',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'GCPD',
#    'respondent-name': 'Public Utility District No. 2 of Grant County, Washington',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 696,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CISO',
#    'respondent-name': 'California Independent System Operator',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 954,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SWPP',
#    'respondent-name': 'Southwest Power Pool',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 36,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PNM',
#    'respondent-name': 'Public Service Company of New Mexico',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'DUK',
#    'respondent-name': 'Duke Energy Carolinas',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 7363,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CHPD',
#    'respondent-name': 'Public Utility District No. 1 of Chelan County',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 623,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SCL',
#    'respondent-name': 'Seattle City Light',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 694,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 10110,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'GRID',
#    'respondent-name': 'Gridforce Energy Management, LLC',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 11,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'GRIF',
#    'respondent-name': 'Griffith Energy, LLC',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 450,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TIDC',
#    'respondent-name': 'Turlock Irrigation District',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 42,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'IPCO',
#    'respondent-name': 'Idaho Power Company',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 612,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'GVL',
#    'respondent-name': 'Gainesville Regional Utilities',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 99,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FPC',
#    'respondent-name': 'Duke Energy Florida, Inc.',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'US48',
#    'respondent-name': 'United States Lower 48',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 2155,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'BANC',
#    'respondent-name': 'Balancing Authority of Northern California',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 1161,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 1,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SRP',
#    'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#    'fueltype': 'WND',
#    'type-name': 'Wind',
#    'value': 93,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PSCO',
#    'respondent-name': 'Public Service Company of Colorado',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 33,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SCEG',
#    'respondent-name': 'Dominion Energy South Carolina, Inc.',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PSEI',
#    'respondent-name': 'Puget Sound Energy, Inc.',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SRP',
#    'respondent-name': 'Salt River Project Agricultural Improvement and Power District',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 2054,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TEN',
#    'respondent-name': 'Tennessee',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 3633,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'TVA',
#    'respondent-name': 'Tennessee Valley Authority',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 9,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1136,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'WALC',
#    'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 253,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FLA',
#    'respondent-name': 'Florida',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 40,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'AECI',
#    'respondent-name': 'Associated Electric Cooperative, Inc.',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 1956,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 21693,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 1161,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 11167,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'NYIS',
#    'respondent-name': 'New York Independent System Operator',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SPA',
#    'respondent-name': 'Southwestern Power Administration',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 236,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FLA',
#    'respondent-name': 'Florida',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 2809,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'JEA',
#    'respondent-name': 'JEA',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 3,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'NUC',
#    'type-name': 'Nuclear',
#    'value': 11192,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'BPAT',
#    'respondent-name': 'Bonneville Power Administration',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 6608,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MISO',
#    'respondent-name': 'Midcontinent Independent System Operator, Inc.',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 26715,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'LDWP',
#    'respondent-name': 'Los Angeles Department of Water and Power',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 212,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CAR',
#    'respondent-name': 'Carolinas',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 1338,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'AZPS',
#    'respondent-name': 'Arizona Public Service Company',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FLA',
#    'respondent-name': 'Florida',
#    'fueltype': 'OIL',
#    'type-name': 'Petroleum',
#    'value': 0,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 12427,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'WALC',
#    'respondent-name': 'Western Area Power Administration - Desert Southwest Region',
#    'fueltype': 'SUN',
#    'type-name': 'Solar',
#    'value': 7,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'MIDW',
#    'respondent-name': 'Midwest',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 23326,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'FPL',
#    'respondent-name': 'Florida Power & Light Co.',
#    'fueltype': 'OTH',
#    'type-name': 'Other',
#    'value': 2256,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'CENT',
#    'respondent-name': 'Central',
#    'fueltype': 'NG',
#    'type-name': 'Natural gas',
#    'value': 8235,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'NW',
#    'respondent-name': 'Northwest',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 12764,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'SE',
#    'respondent-name': 'Southeast',
#    'fueltype': 'COL',
#    'type-name': 'Coal',
#    'value': 4126,
#    'value-units': 'megawatthours'},
#   {'period': '2023-01-01T00',
#    'respondent': 'PJM',
#    'respondent-name': 'PJM Interconnection, LLC',
#    'fueltype': 'WAT',
#    'type-name': 'Hydro',
#    'value': 2477,
#    'value-units': 'megawatthours'},
#   ...]]

# %%
## length
len(all_data)
# Out:
# 12

# %%
## use itertools to flatten list with nested lists
import itertools

# %%
## flatten nested lists
flat_data = list(itertools.chain(*all_data))

# %%
## convert to df
df = pd.DataFrame(flat_data)
df
# Out:
#               period respondent  \
# 0      2023-01-07T00       ERCO
# 1      2023-01-07T00       CPLW
# 2      2023-01-07T00       AECI
# 3      2023-01-07T00       CISO
# 4      2023-01-07T00       ISNE
# ...              ...        ...
# 56255  2023-01-01T00       PACE
# 56256  2023-01-01T00         NY
# 56257  2023-01-01T00       FMPP
# 56258  2023-01-01T00         NW
# 56259  2023-01-01T00       LGEE
#
#                                          respondent-name fueltype  \
# 0            Electric Reliability Council of Texas, Inc.      WND
# 1                              Duke Energy Progress West      COL
# 2                  Associated Electric Cooperative, Inc.      WND
# 3                 California Independent System Operator      WAT
# 4                                        ISO New England       NG
# ...                                                  ...      ...
# 56255                                    PacifiCorp East       NG
# 56256                                           New York      SUN
# 56257                       Florida Municipal Power Pool       NG
# 56258                                          Northwest      OTH
# 56259  Louisville Gas and Electric Company and Kentuc...      SUN
#
#          type-name    value    value-units
# 0             Wind  17873.0  megawatthours
# 1             Coal      0.0  megawatthours
# 2             Wind    261.0  megawatthours
# 3            Hydro   2394.0  megawatthours
# 4      Natural gas   8095.0  megawatthours
# ...            ...      ...            ...
# 56255  Natural gas   1529.0  megawatthours
# 56256        Solar      0.0  megawatthours
# 56257  Natural gas   1202.0  megawatthours
# 56258        Other   1004.0  megawatthours
# 56259        Solar      0.0  megawatthours
#
# [56260 rows x 7 columns]

# %%
fips_codes = {
    'Alabama': '01',
    'Alaska': '02',
    'Arizona': '04',
    'Arkansas': '05',
    'California': '06',
    'Colorado': '08',
    'Connecticut': '09',
    'Delaware': '10',
    'Florida': '12',
    'Georgia': '13',
    'Hawaii': '15',
    'Idaho': '16',
    'Illinois': '17',
    'Indiana': '18',
    'Iowa': '19',
    'Kansas': '20',
    'Kentucky': '21',
    'Louisiana': '22',
    'Maine': '23',
    'Maryland': '24',
    'Massachusetts': '25',
    'Michigan': '26',
    'Minnesota': '27',
    'Mississippi': '28',
    'Missouri': '29',
    'Montana': '30',
    'Nebraska': '31',
    'Nevada': '32',
    'New Hampshire': '33',
    'New Jersey': '34',
    'New Mexico': '35',
    'New York': '36',
    'North Carolina': '37',
    'North Dakota': '38',
    'Ohio': '39',
    'Oklahoma': '40',
    'Oregon': '41',
    'Pennsylvania': '42',
    'Rhode Island': '44',
    'South Carolina': '45',
    'South Dakota': '46',
    'Tennessee': '47',
    'Texas': '48',
    'Utah': '49',
    'Vermont': '50',
    'Virginia': '51',
    'Washington': '53',
    'West Virginia': '54',
    'Wisconsin': '55',
    'Wyoming': '56',
    'District of Columbia': '11',
    'Puerto Rico': '72'
}
