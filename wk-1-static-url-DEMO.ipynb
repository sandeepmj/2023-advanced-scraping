# %% [markdown]
# # Scraping a fixed URL site
#
# We'll often encounter website where the url never changes. Here are a few examples:
#
# - <a href="https://eportal.miteco.gob.es/BoleHWeb/">Ministry for the Ecological Transition and the Demographic Challenge</a>.
# - <a href="https://www.seethroughny.net/">See Through NY</a>
# - <a href="https://restructuring.ra.kroll.com/pge/Home-ClaimInfo">PG&E fire victim creditors</a>
#
# From <a href="https://infopost.enbridge.com/InfoPost/">this homepage</a>, we want to scrape the critical notices for the Algonquin Gas Transmission.
#
# Let's explore the site to come up with our scrape strategy.

# %%
## import libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
## target url
url = "https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=AG&type=CRI"

# %%
## response

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
type(response.text)
# Out:
# str

# %%
## capture all tables
all_data = pd.read_html(response.text)
all_data
# Out:
# [                Notice Type        Posted Date/Time  \
#  0       Capacity Constraint  10/23/2023 03:36:53 PM
#  1       Capacity Constraint  10/22/2023 03:05:11 PM
#  2       Capacity Constraint  10/21/2023 03:29:00 PM
#  3       Capacity Constraint  10/20/2023 03:41:37 PM
#  4       Capacity Constraint  10/19/2023 03:10:00 PM
#  ..                      ...                     ...
#  118     Capacity Constraint  07/29/2023 02:45:36 PM
#  119     Capacity Constraint  07/28/2023 03:49:14 PM
#  120  Operational Flow Order  07/28/2023 07:11:00 AM
#  121     Capacity Constraint  07/27/2023 03:03:44 PM
#  122     Capacity Constraint  07/26/2023 02:57:00 PM
#
#      Notice Effective Date/Time    Notice End Date/Time  Notice Identifier  \
#  0       10/24/2023 09:00:00 AM  10/25/2023 09:00:00 AM             139536
#  1       10/23/2023 09:00:00 AM  10/24/2023 09:00:00 AM             139482
#  2       10/22/2023 09:00:00 AM  10/23/2023 09:00:00 AM             139455
#  3       10/21/2023 09:00:00 AM  10/22/2023 09:00:00 AM             139420
#  4       10/20/2023 09:00:00 AM  10/21/2023 09:00:00 AM             139374
#  ..                         ...                     ...                ...
#  118     07/30/2023 09:00:00 AM  07/31/2023 09:00:00 AM             136178
#  119     07/29/2023 09:00:00 AM  07/30/2023 09:00:00 AM             136161
#  120     07/29/2023 09:00:00 AM  10/26/2023 09:00:00 AM             136132
#  121     07/28/2023 09:00:00 AM  07/29/2023 09:00:00 AM             136114
#  122     07/27/2023 09:00:00 AM  07/28/2023 09:00:00 AM             136078
#
#                                             Subject  Response Date/Time
#  0           AGT Pipeline Conditions for 10/24/2023                 NaN
#  1           AGT Pipeline Conditions for 10/23/2023                 NaN
#  2           AGT Pipeline Conditions for 10/22/2023                 NaN
#  3           AGT Pipeline Conditions for 10/21/2023                 NaN
#  4           AGT Pipeline Conditions for 10/20/2023                 NaN
#  ..                                             ...                 ...
#  118          AGT Pipeline Conditions for 7/30/2023                 NaN
#  119          AGT Pipeline Conditions for 7/29/2023                 NaN
#  120  AGT Operational Flow Order -- LIFTED EFF 7/29                 NaN
#  121          AGT Pipeline Conditions for 7/28/2023                 NaN
#  122          AGT Pipeline Conditions for 7/27/2023                 NaN
#
#  [123 rows x 7 columns]]

# %%
df = all_data[0]
df
# Out:
#                 Notice Type        Posted Date/Time  \
# 0       Capacity Constraint  10/23/2023 03:36:53 PM
# 1       Capacity Constraint  10/22/2023 03:05:11 PM
# 2       Capacity Constraint  10/21/2023 03:29:00 PM
# 3       Capacity Constraint  10/20/2023 03:41:37 PM
# 4       Capacity Constraint  10/19/2023 03:10:00 PM
# ..                      ...                     ...
# 118     Capacity Constraint  07/29/2023 02:45:36 PM
# 119     Capacity Constraint  07/28/2023 03:49:14 PM
# 120  Operational Flow Order  07/28/2023 07:11:00 AM
# 121     Capacity Constraint  07/27/2023 03:03:44 PM
# 122     Capacity Constraint  07/26/2023 02:57:00 PM
#
#     Notice Effective Date/Time    Notice End Date/Time  Notice Identifier  \
# 0       10/24/2023 09:00:00 AM  10/25/2023 09:00:00 AM             139536
# 1       10/23/2023 09:00:00 AM  10/24/2023 09:00:00 AM             139482
# 2       10/22/2023 09:00:00 AM  10/23/2023 09:00:00 AM             139455
# 3       10/21/2023 09:00:00 AM  10/22/2023 09:00:00 AM             139420
# 4       10/20/2023 09:00:00 AM  10/21/2023 09:00:00 AM             139374
# ..                         ...                     ...                ...
# 118     07/30/2023 09:00:00 AM  07/31/2023 09:00:00 AM             136178
# 119     07/29/2023 09:00:00 AM  07/30/2023 09:00:00 AM             136161
# 120     07/29/2023 09:00:00 AM  10/26/2023 09:00:00 AM             136132
# 121     07/28/2023 09:00:00 AM  07/29/2023 09:00:00 AM             136114
# 122     07/27/2023 09:00:00 AM  07/28/2023 09:00:00 AM             136078
#
#                                            Subject  Response Date/Time
# 0           AGT Pipeline Conditions for 10/24/2023                 NaN
# 1           AGT Pipeline Conditions for 10/23/2023                 NaN
# 2           AGT Pipeline Conditions for 10/22/2023                 NaN
# 3           AGT Pipeline Conditions for 10/21/2023                 NaN
# 4           AGT Pipeline Conditions for 10/20/2023                 NaN
# ..                                             ...                 ...
# 118          AGT Pipeline Conditions for 7/30/2023                 NaN
# 119          AGT Pipeline Conditions for 7/29/2023                 NaN
# 120  AGT Operational Flow Order -- LIFTED EFF 7/29                 NaN
# 121          AGT Pipeline Conditions for 7/28/2023                 NaN
# 122          AGT Pipeline Conditions for 7/27/2023                 NaN
#
# [123 rows x 7 columns]

# %%
notice_IDs = df["Notice Identifier"].to_list()

# %%
notice_IDs
# Out:
# [139536,
#  139482,
#  139455,
#  139420,
#  139374,
#  139316,
#  139278,
#  139258,
#  139218,
#  139200,
#  139182,
#  139140,
#  139018,
#  139071,
#  139070,
#  139010,
#  138969,
#  138918,
#  138881,
#  138877,
#  138841,
#  138804,
#  138744,
#  138709,
#  138670,
#  138666,
#  138650,
#  138602,
#  138586,
#  138563,
#  138562,
#  138546,
#  138525,
#  138513,
#  138494,
#  138433,
#  138416,
#  138399,
#  138358,
#  138338,
#  138333,
#  138284,
#  138253,
#  138239,
#  138182,
#  138050,
#  138061,
#  138045,
#  138014,
#  137980,
#  137964,
#  137950,
#  137918,
#  137892,
#  137869,
#  137848,
#  137812,
#  137796,
#  137770,
#  137745,
#  137718,
#  137692,
#  137672,
#  137671,
#  137656,
#  137624,
#  137620,
#  137590,
#  137586,
#  137550,
#  137505,
#  137501,
#  137497,
#  137457,
#  137428,
#  137398,
#  137360,
#  137314,
#  137330,
#  137296,
#  137261,
#  137235,
#  137218,
#  137189,
#  137174,
#  137124,
#  137097,
#  137095,
#  137020,
#  137036,
#  137013,
#  136971,
#  136935,
#  136911,
#  136856,
#  136880,
#  136855,
#  136839,
#  136811,
#  136758,
#  136743,
#  136711,
#  136681,
#  136666,
#  136616,
#  136565,
#  136549,
#  136515,
#  136502,
#  136484,
#  136451,
#  136424,
#  136405,
#  136362,
#  136342,
#  136290,
#  136258,
#  136206,
#  136178,
#  136161,
#  136132,
#  136114,
#  136078]

# %%
base_start = "https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1="
base_end = "&type=CRI&Embed=2&pipe=AG"

# %%
links_details = [f"{base_start}{notice_id}{base_end}" for notice_id in notice_IDs]
links_details
# Out:
# ['https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139536&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139482&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139455&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139420&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139374&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139316&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139278&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139258&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139218&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139200&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139182&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139140&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139018&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139071&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139070&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=139010&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138969&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138918&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138881&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138877&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138841&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138804&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138744&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138709&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138670&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138666&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138650&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138602&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138586&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138563&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138562&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138546&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138525&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138513&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138494&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138433&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138416&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138399&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138358&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138338&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138333&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138284&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138253&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138239&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138182&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138050&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138061&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138045&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=138014&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137980&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137964&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137950&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137918&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137892&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137869&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137848&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137812&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137796&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137770&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137745&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137718&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137692&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137672&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137671&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137656&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137624&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137620&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137590&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137586&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137550&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137505&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137501&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137497&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137457&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137428&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137398&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137360&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137314&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137330&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137296&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137261&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137235&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137218&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137189&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137174&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137124&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137097&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137095&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137020&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137036&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=137013&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136971&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136935&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136911&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136856&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136880&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136855&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136839&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136811&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136758&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136743&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136711&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136681&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136666&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136616&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136565&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136549&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136515&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136502&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136484&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136451&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136424&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136405&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136362&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136342&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136290&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136258&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136206&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136178&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136161&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136132&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136114&type=CRI&Embed=2&pipe=AG',
#  'https://infopost.enbridge.com/InfoPost/NoticeListDetail.asp?strKey1=136078&type=CRI&Embed=2&pipe=AG']

# %% [markdown]
# # What if we wanted to scrape ALL the gas lines?

# %%
## capture all the biz units

# %%
homepage_url = "https://infopost.enbridge.com/InfoPost/"
response = requests.get(homepage_url)
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!-- template.asp -->
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="favicon.ico" rel="shortcut icon"/>
# <link href="css/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/font-awesome-ie7.min.css" rel="stylesheet">
# <link href="css/font-awesome.css" rel="stylesheet"/>
# <link href="css/link.css" rel="stylesheet">
# <link href="css/print.css" media="print" rel="stylesheet"/>
# <link href="css/infopost-custom.css" media="screen" rel="stylesheet"/>
# <link href="css/environment.css" media="screen" rel="stylesheet"/>
# <!-- HTML5 shim, for IE6-9 support of HTML5 elements -->
# <!--[if lt IE 9]>
# 	<link href="css/link-ie.css" rel="stylesheet" />
# 	<script src="scripts/html5shiv.js" type="text/javascript"></script>
# 	<script src="scripts/html5shiv-printshiv.js" type="text/javascript"></script>
# 	<script src="scripts/respond.js" type="text/javascript"></script>
# <![endif]-->
# <style>
# </style>
# <script src="scripts/jquery-1.11.0.min.js" type="text/javascript"></script>
# <script src="scripts/jquery-ui-1.11.1.min.js" type="text/javascript"></script>
# <script src="scripts/bootstrap-3.1.1.min.js" type="text/javascript"></script>
# <script src="scripts/CommonScripts.js" type="text/javascript"></script>
# <script src="scripts/cookies.js" type="text/javascript"></script>
# <script language="JavaScript" src="scripts/load_popup-1.2.js" type="Text/JavaScript"></script>
# <title>LINK® Informational Postings</title>
# <script>
# 	var pipeCodeList = 'AG|BGS|BIG|BSP|EG|ET|GB|GPL|MCGP|MB|MNCA|MNUS|MR|NPC|NXCA|NXUS|SESH|SG|SR|STT|TE|TPGS|VCP|WRGS|';
# var pipeNameList = 'Algonquin|Bobcat Gas Storage|BIG Pipeline|Big Sandy Pipeline|MHP Egan|East Tennessee|Garden Banks|Generation  Pipeline|Mississippi Canyon|MHP Moss Bluff|Maritimes & Northeast Canada|Maritimes & Northeast U.S.|Manta Ray Offshore Gathering Company|Nautilus Pipeline Company|NEXUS ULC|NEXUS U.S.|Southeast Supply Header|Saltville|Steckman Ridge|Sabal Trail|Texas Eastern|Tres Palacios Gas Storage LLC|Valley Crossing Pipeline|Walker Ridge Gathering System |';
# var pipeLegalCode = 'AG|BGS|BIG|BSP|EG|ET|GB|GPL|MCGP|MB|MNCA|MNUS|MR|NPC|NXCA|NXUS|SESH|SG|SR|STT|TE|TPGS|VCP|WRGS|';var pipeLegalName = 'Algonquin Gas Transmission, LLC - 006951446|Bobcat Gas Storage - 614834559|Brazoria Interconnector Gas Pipeline, LLC  - 809456739|Big Sandy Pipeline - 968195714|Egan Hub Storage, LLC - 835460478|East Tennessee Natural Gas, LLC - 007921323|Garden Banks Gas Pipeline, LLC - 966981599|Generation Pipeline, LLC - 036638044|Mississippi Canyon Gas Pipeline, LLC - 946822749|Moss Bluff Hub, LLC - 031369874|Maritimes & Northeast Pipeline, Canada - 251930723|Maritimes & Northeast Pipeline, L.L.C. - 081787256|Manta Ray Offshore Gathering Company, L.L.C. - 030524854|Nautilus Pipeline Company, L.L.C. - 176824738|NEXUS CAPACITY SERVICES, ULC - 080685281|NEXUS Gas Transmission, LLC - 080151107|Southeast Supply Header, LLC - 808264746|Saltville Gas Storage Company L.L.C - 791287274|Steckman Ridge, LP - 827593182|Sabal Trail Transmission - 930373670|Texas Eastern Transmission, LP - 007932908| Tres Palacios Gas Storage LLC - 791204600|Valley Crossing Pipeline, LLC - 080429578| Walker Ridge Gathering System, L.L.C. - |';var pipeLineAbbr = 'AGT|BGS|BIG|BSP|EHP|ETNG|GB|GPL|MCGP|MBHP|MNCA|MNUS|MR|NPC|NXCA|NXUS|SESH|SGSC|SR|STT|TE|TPGS|VCP|WRGS|';
# 	function showWeather() {
# 		window.open("Weather.asp","Weather","toolbar=no,menubar=no,resizable=yes,scrollbars=no");
# 		return false;
# 	}
#
# 	function displayPopup(){
# 		var url = window.location.href ;
# 		var sURL = "";
#
# 		if(url.toLowerCase().indexOf('spectraenergy.com') > 1)
# 			displayPopup1('05/06/2021','08/08/2017');
#
# 	}
# </script>
# </link></link></head>
# <body class="html-body" onload="setupPipes(''); displayPopup();">
# <div class="container-fluid screen-padding">
# <div class="header">
# <div class="branding hidden-xs">
# <div class="nav-right">
# <ul class="list-inline">
# <li class="hidden-print"><a href="https://link.enbridge.com/Tutorials.asp" target="_blank">Tutorials</a></li>
# <li class="hidden-print"><a href='javascript:void(window.open("https://link.enbridge.com/Contact.asp", "", "width=750,height=600,menubar=0,toolbar=0,screenX=300,screenY=300, scrollbars=yes"));'>Contact Us</a></li>
# <li class="hidden-print"><a href="http://www.enbridge.com" target="_blank"></a><img alt="Enbridge Inc." src="/images/CORPORATE_LOGO.jpg"/></li>
# </ul>
# </div>
# <img alt="LINK System" src="/images/link_logo_infopost.gif"/>
# <div class="visible-print screen-title"></div>
# <div class="clear"></div>
# </div>
# <nav class="navbar navbar-print">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#Navbar1" data-toggle="collapse" id="navbar1-toggle-button" title="Show/Hide Menu" type="button">
# <span class="sr-only">Toggle navigation</span>
# <i class="fa fa-bars"></i>
# </button>
# <a class="navbar-brand" data-placement="bottom" data-toggle="tooltip" href="./" title="LINK® Informational Postings"><i class="fa fa-home"></i></a>
# </div>
# <div class="collapse navbar-collapse" id="Navbar1">
# <ul class="nav navbar-nav" id="select-pipe-navbar">
# <li class="Pipe-dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="line-height: 15px; font-size:11px;" title="Select Business Unit">Select Business Unit<b class="caret"></b></a>
# <ul class="dropdown-menu select-pipe-dropdown-menu" id="dropdown">
# <li><a href="AGHome.asp?Pipe=AG">Algonquin (AGT)</a></li><li><a href="BGSHome.asp?Pipe=BGS">Bobcat Gas Storage (BGS)</a></li><li><a href="BIGHome.asp?Pipe=BIG">BIG Pipeline (BIG)</a></li><li><a href="BSPHome.asp?Pipe=BSP">Big Sandy Pipeline (BSP)</a></li><li><a href="EGHome.asp?Pipe=EG">MHP Egan (EHP)</a></li><li><a href="ETHome.asp?Pipe=ET">East Tennessee (ETNG)</a></li><li><a href="GBHome.asp?Pipe=GB">Garden Banks (GB)</a></li><li><a href="GPLHome.asp?Pipe=GPL">Generation  Pipeline (GPL)</a></li><li><a href="MCGPHome.asp?Pipe=MCGP">Mississippi Canyon (MCGP)</a></li><li><a href="MBHome.asp?Pipe=MB">MHP Moss Bluff (MBHP)</a></li><li><a href="MNCAHome.asp?Pipe=MNCA">Maritimes &amp; Northeast Canada (MNCA)</a></li><li><a href="MNUSHome.asp?Pipe=MNUS">Maritimes &amp; Northeast U.S. (MNUS)</a></li><li><a href="MRHome.asp?Pipe=MR">Manta Ray Offshore Gathering Company (MR)</a></li><li><a href="NPCHome.asp?Pipe=NPC">Nautilus Pipeline Company (NPC)</a></li><li><a href="NXCAHome.asp?Pipe=NXCA">NEXUS ULC (NXCA)</a></li><li><a href="NXUSHome.asp?Pipe=NXUS">NEXUS U.S. (NXUS)</a></li><li><a href="SESHHome.asp?Pipe=SESH">Southeast Supply Header (SESH)</a></li><li><a href="SGHome.asp?Pipe=SG">Saltville (SGSC)</a></li><li><a href="SRHome.asp?Pipe=SR">Steckman Ridge (SR)</a></li><li><a href="STTHome.asp?Pipe=STT">Sabal Trail (STT)</a></li><li><a href="TEHome.asp?Pipe=TE">Texas Eastern (TE)</a></li><li><a href="TPGSHome.asp?Pipe=TPGS">Tres Palacios Gas Storage LLC (TPGS)</a></li><li><a href="VCPHome.asp?Pipe=VCP">Valley Crossing Pipeline (VCP)</a></li><li><a href="WRGSHome.asp?Pipe=WRGS">Walker Ridge Gathering System  (WRGS)</a></li>
# </ul>
# </li>
# <li>
# <a data-placement="bottom" data-toggle="tooltip" href="https://link.enbridge.com//CustomerActivitiesLogin.asp" style="font-size:11px;" title="LINK® Customer Login">Customer Activities (Login)</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="page-title no-print">
# <div class="text-container screen-title"></div>
# <div class="system-time" style="margin-top: -10px;">
# <script>
# 					var serverTime = new Date('10/24/2023 10:08:14 AM');
#
# 					var mm = serverTime.getMonth()+1;
# 					var dd = serverTime.getDate();
# 					var yyyy = serverTime.getFullYear();
# 					var date = mm + "/" + dd + "/" + yyyy;
# 					document.write('<span id="systemDate" class="clock hidden-xs badge badge-info">'+date+'</span>');
#
# 				</script>
# </div>
# <div class="environment" id="envBadge">
# <span class="hidden-xs badge badge-success" id="environmentBadge"> InfoPost QA </span>
# </div>
# </div>
# <p class="hidden-xs tiny-vertical-pad"></p>
# </div>
# <script>
# /*$(document).ready(function(){
#     $('[data-toggle="tooltip"]').tooltip();
# 	$('.navbar-toggle').tooltip();
# });*/
# </script>
# <div class="container">
# <div class="col-sm-6">
# <div class="row-fluid">
# <div class="text_box">
# <h2>Customer Support</h2>
# <div class="accordion-inner">
# <p>
# 						For LINK® application support, please call 1-800-827-LINK (5465),
# 						713-989-LINK, or email the LINK® Help Desk
# 						<a href="mailto:link-help@enbridge.com"><i class="fa fa-envelope"></i></a>. Additional online support can be found on the
# 						<a href="https://link.enbridge.com/Tutorials.asp" target="_blank">tutorial page</a>. For after hours business support, please contact Volume Management at 713-627-5059.
# 					</p>
# </div>
# </div>
# <div class="text_box">
# <h2>Critical Notices </h2>
# <div class="accordion-inner">
# <iframe id="Critical" src="https://infopost.enbridge.com/InfoPostFrameContent/IframeLinkCriticalNotices.asp" style="border:none;" width="100%"></iframe>
# </div>
# </div>
# <div class="text_box">
# <h2>Non-Critical Notices </h2>
# <div class="accordion-inner">
# <iframe id="nonCritical" src="https://infopost.enbridge.com/InfoPostFrameContent/IframeLinkNonCriticalNotices.asp" style="border:none;" width="100%"></iframe>
# </div>
# </div>
# </div> <!-- raw-fluid -->
# </div><!--col-sm-6 -->
# <div class="col-sm-6">
# <div class="row-fluid">
# <div class="carousel slide hidden-xs" data-interval="3000" id="welcome-carousel" style="margin-top: 7px;margin-bottom: 20px;">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#welcome-carousel"></li>
# <li data-slide-to="1" data-target="#welcome-carousel"></li>
# <li data-slide-to="2" data-target="#welcome-carousel"></li>
# <li data-slide-to="3" data-target="#welcome-carousel"></li>
# </ol>
# <div class="carousel-inner ui-widget ui-widget-content ui-corner-all">
# <div class="item active" id="welcome">
# <a href="http://www.enbridge.com" target="_blank">
# <img alt="LINK System" src="/images/linksystem-carousel-notext.png">
# <div class="carousel-welcome-container" style="position: relative;">
# <div class="carousel-welcome-text">
# <p>Welcome to Enbridge Inc's<br/>LINK® System Informational Postings.</p>
# <p>We create superior and sustainable value by providing<br/>natural gas gathering and processing, transmission, storage<br/>and distribution services.<br/></p>
# <p>For more information go to www.enbridge.com</p>
# </div>
# </div>
# </img></a>
# <div class="carousel-caption">
# <h4>Welcome</h4>
# </div>
# </div>
# <div class="item" id="assets">
# <a href="https://link.enbridge.com/CorporateAssets.asp" target="_blank">
# <img alt="Click to view Enbridge Assests" src="/images/CORPORATE_Asset_Map.png">
# </img></a>
# <div class="carousel-caption">
# <h4>Assets</h4>
# </div>
# </div>
# <div class="item" id="weather">
# <a href="https://link.enbridge.com/Weather.asp" target="_blank">
# <img alt="Click to view weather" src="https://link.enbridge.com//WeatherImages/"/>
# </a>
# <div class="carousel-caption">
# <h4>Weather</h4>
# </div>
# </div>
# <div class="item" id="board">
# <a href="LinkBoardTab.asp" target="_blank">
# <img alt="Click to read more about LINK Board" src="https://link.enbridge.com//images/LinkBoardTabImage.JPG"/>
# </a>
# <div class="carousel-caption">
# <h4>The Board</h4>
# </div>
# </div>
# </div>
# <a class="carousel-control left" data-slide="prev" href="#welcome-carousel">‹</a>
# <a class="carousel-control right" data-slide="next" href="#welcome-carousel">›</a>
# </div> <!-- welcome-carousel -->
# <div class="text_box">
# <h2> Public Information</h2>
# <div class="accordion-inner">
# <ul class="bulletedUlist" style="margin-top: 10px;">
# <li>
# <a href="https://link.enbridge.com/CreditInformation.asp" target="_blank" title="Submit Credit Application">Submit Credit Application</a>
# </li>
# <li>
# <a href="https://link.enbridge.com/Notification/Introduction" target="_blank" title="Email Notification">Sign Up For Publicly Available Notices</a>
# </li>
# <li>
# <a href="https://link.enbridge.com/TariffNotification/tariffemail.asp" target="_blank">Sign up to Receive Tariff Filings For Our Regulated Facilities</a>
# </li>
# <li>
# <a href='javascript:void(window.open("FormsAndTechnical.asp", "", "width=750,height=500,menubar=0,toolbar=0,screenX=300,screenY=300"));'>Forms &amp; Technical Requirements </a>
# </li>
# <li>
# <a href="http://www.enbridge.com/" target="_blank">Enbridge Inc.'s Internet Site</a>
# </li>
# <li>
# <a href="http://www.enbridge.com/projects-and-infrastructure/projects" target="_blank">Enbridge Inc.'s Projects</a>
# </li>
# <li>
# <a href="https://link.enbridge.com/view/TE_Appalachian_Shale_Supply.pdf" target="_blank" title="TE Appalachian Shale Supply">TE Appalachian Shale Supply</a>
# </li>
# <li>
# <a href="https://link.enbridge.com/view/TE_Appalachian_Shale_Supply_Map.pdf" target="_blank" title="TE Appalachian Shale Supply Map">TE Appalachian Shale Supply Map</a>
# </li>
# </ul>
# </div>
# <div class="clear_float"></div>
# </div>
# </div> <!-- raw-fluid -->
# </div><!--col-sm-6 -->
# </div> <!--container-fluid -->
# <p class="small-vertical-pad"></p>
# <div class="span12 copyright-footer center" style="text-align: center;">
# <div id="footer">
# <script>
# 			currentDtTm = new Date();
# 			var cpdate = currentDtTm.getFullYear();
# 			document.write('<span>&copy;&nbsp;Copyright 1998-'+cpdate +'&nbsp;</span>');
# 		</script>
# <span><a href="http://www.enbridge.com/privacy-statement" target="_blank">Privacy</a> </span>
# <span><a href="http://www.enbridge.com/termsofuse" target="_blank">Terms</a> </span>
# <a href="SiteMap.asp" target="_blank" title="Site Map">Site Map</a>
# </div>
# </div>
# </div> <!--container-fluid screen-padding -->
# <script>
#
# $(document).ready(function () {
# 	$('.carousel').carousel('cycle');
# });
#
# </script>
# </body>
# </html>

# %%
dropdown_list = soup.find(id="dropdown")
dropdown_list
# Out:
# <ul class="dropdown-menu select-pipe-dropdown-menu" id="dropdown">
# <li><a href="AGHome.asp?Pipe=AG">Algonquin (AGT)</a></li><li><a href="BGSHome.asp?Pipe=BGS">Bobcat Gas Storage (BGS)</a></li><li><a href="BIGHome.asp?Pipe=BIG">BIG Pipeline (BIG)</a></li><li><a href="BSPHome.asp?Pipe=BSP">Big Sandy Pipeline (BSP)</a></li><li><a href="EGHome.asp?Pipe=EG">MHP Egan (EHP)</a></li><li><a href="ETHome.asp?Pipe=ET">East Tennessee (ETNG)</a></li><li><a href="GBHome.asp?Pipe=GB">Garden Banks (GB)</a></li><li><a href="GPLHome.asp?Pipe=GPL">Generation  Pipeline (GPL)</a></li><li><a href="MCGPHome.asp?Pipe=MCGP">Mississippi Canyon (MCGP)</a></li><li><a href="MBHome.asp?Pipe=MB">MHP Moss Bluff (MBHP)</a></li><li><a href="MNCAHome.asp?Pipe=MNCA">Maritimes &amp; Northeast Canada (MNCA)</a></li><li><a href="MNUSHome.asp?Pipe=MNUS">Maritimes &amp; Northeast U.S. (MNUS)</a></li><li><a href="MRHome.asp?Pipe=MR">Manta Ray Offshore Gathering Company (MR)</a></li><li><a href="NPCHome.asp?Pipe=NPC">Nautilus Pipeline Company (NPC)</a></li><li><a href="NXCAHome.asp?Pipe=NXCA">NEXUS ULC (NXCA)</a></li><li><a href="NXUSHome.asp?Pipe=NXUS">NEXUS U.S. (NXUS)</a></li><li><a href="SESHHome.asp?Pipe=SESH">Southeast Supply Header (SESH)</a></li><li><a href="SGHome.asp?Pipe=SG">Saltville (SGSC)</a></li><li><a href="SRHome.asp?Pipe=SR">Steckman Ridge (SR)</a></li><li><a href="STTHome.asp?Pipe=STT">Sabal Trail (STT)</a></li><li><a href="TEHome.asp?Pipe=TE">Texas Eastern (TE)</a></li><li><a href="TPGSHome.asp?Pipe=TPGS">Tres Palacios Gas Storage LLC (TPGS)</a></li><li><a href="VCPHome.asp?Pipe=VCP">Valley Crossing Pipeline (VCP)</a></li><li><a href="WRGSHome.asp?Pipe=WRGS">Walker Ridge Gathering System  (WRGS)</a></li>
# </ul>

# %%
## get atags
a_tags = dropdown_list.find_all("a")
a_tags
# Out:
# [<a href="AGHome.asp?Pipe=AG">Algonquin (AGT)</a>,
#  <a href="BGSHome.asp?Pipe=BGS">Bobcat Gas Storage (BGS)</a>,
#  <a href="BIGHome.asp?Pipe=BIG">BIG Pipeline (BIG)</a>,
#  <a href="BSPHome.asp?Pipe=BSP">Big Sandy Pipeline (BSP)</a>,
#  <a href="EGHome.asp?Pipe=EG">MHP Egan (EHP)</a>,
#  <a href="ETHome.asp?Pipe=ET">East Tennessee (ETNG)</a>,
#  <a href="GBHome.asp?Pipe=GB">Garden Banks (GB)</a>,
#  <a href="GPLHome.asp?Pipe=GPL">Generation  Pipeline (GPL)</a>,
#  <a href="MCGPHome.asp?Pipe=MCGP">Mississippi Canyon (MCGP)</a>,
#  <a href="MBHome.asp?Pipe=MB">MHP Moss Bluff (MBHP)</a>,
#  <a href="MNCAHome.asp?Pipe=MNCA">Maritimes &amp; Northeast Canada (MNCA)</a>,
#  <a href="MNUSHome.asp?Pipe=MNUS">Maritimes &amp; Northeast U.S. (MNUS)</a>,
#  <a href="MRHome.asp?Pipe=MR">Manta Ray Offshore Gathering Company (MR)</a>,
#  <a href="NPCHome.asp?Pipe=NPC">Nautilus Pipeline Company (NPC)</a>,
#  <a href="NXCAHome.asp?Pipe=NXCA">NEXUS ULC (NXCA)</a>,
#  <a href="NXUSHome.asp?Pipe=NXUS">NEXUS U.S. (NXUS)</a>,
#  <a href="SESHHome.asp?Pipe=SESH">Southeast Supply Header (SESH)</a>,
#  <a href="SGHome.asp?Pipe=SG">Saltville (SGSC)</a>,
#  <a href="SRHome.asp?Pipe=SR">Steckman Ridge (SR)</a>,
#  <a href="STTHome.asp?Pipe=STT">Sabal Trail (STT)</a>,
#  <a href="TEHome.asp?Pipe=TE">Texas Eastern (TE)</a>,
#  <a href="TPGSHome.asp?Pipe=TPGS">Tres Palacios Gas Storage LLC (TPGS)</a>,
#  <a href="VCPHome.asp?Pipe=VCP">Valley Crossing Pipeline (VCP)</a>,
#  <a href="WRGSHome.asp?Pipe=WRGS">Walker Ridge Gathering System  (WRGS)</a>]

# %%
## get hrefs

hrefs = [a_tag.get("href") for a_tag in a_tags]
hrefs
# Out:
# ['AGHome.asp?Pipe=AG',
#  'BGSHome.asp?Pipe=BGS',
#  'BIGHome.asp?Pipe=BIG',
#  'BSPHome.asp?Pipe=BSP',
#  'EGHome.asp?Pipe=EG',
#  'ETHome.asp?Pipe=ET',
#  'GBHome.asp?Pipe=GB',
#  'GPLHome.asp?Pipe=GPL',
#  'MCGPHome.asp?Pipe=MCGP',
#  'MBHome.asp?Pipe=MB',
#  'MNCAHome.asp?Pipe=MNCA',
#  'MNUSHome.asp?Pipe=MNUS',
#  'MRHome.asp?Pipe=MR',
#  'NPCHome.asp?Pipe=NPC',
#  'NXCAHome.asp?Pipe=NXCA',
#  'NXUSHome.asp?Pipe=NXUS',
#  'SESHHome.asp?Pipe=SESH',
#  'SGHome.asp?Pipe=SG',
#  'SRHome.asp?Pipe=SR',
#  'STTHome.asp?Pipe=STT',
#  'TEHome.asp?Pipe=TE',
#  'TPGSHome.asp?Pipe=TPGS',
#  'VCPHome.asp?Pipe=VCP',
#  'WRGSHome.asp?Pipe=WRGS']

# %%
## import regex library
import re

# %%
## capture pattern

pat = re.compile(r"Pipe=(\w+)")

# %%
unit_codes = []
for unit_code in hrefs:
#     print(unit_code)
    unit_codes.append(pat.findall(unit_code)[0])
    
unit_codes
# Out:
# ['AG',
#  'BGS',
#  'BIG',
#  'BSP',
#  'EG',
#  'ET',
#  'GB',
#  'GPL',
#  'MCGP',
#  'MB',
#  'MNCA',
#  'MNUS',
#  'MR',
#  'NPC',
#  'NXCA',
#  'NXUS',
#  'SESH',
#  'SG',
#  'SR',
#  'STT',
#  'TE',
#  'TPGS',
#  'VCP',
#  'WRGS']

# %%
url_start = "https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe="
end_url = "&type=CRI"

# %%
links = [f"{url_start}{unit_code}{end_url}" for unit_code in unit_codes]
links
# Out:
# ['https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=AG&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=BGS&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=BIG&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=BSP&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=EG&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=ET&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=GB&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=GPL&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MCGP&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MB&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MNCA&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MNUS&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MR&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=NPC&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=NXCA&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=NXUS&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=SESH&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=SG&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=SR&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=STT&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=TE&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=TPGS&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=VCP&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=WRGS&type=CRI']

# %%
import time
from random import randrange

# %%
broken_url = []
df_list = []
total_links = len(unit_codes)
counter = 1

for unit_code in unit_codes:
    print(f"Scraping {counter} of {total_links}")
    counter += 1
    target_link = f"{url_start}{unit_code}{end_url}"
    response = requests.get(target_link)
    try:
        data = pd.read_html(response.text)
        df = data[0]
        df["unit"] = unit_code
        df_list.append(df)
    except:
        print(f"{unit_code} was busted or had no table")
        broken_url.append(target_link)
    finally:
        snooze = randrange(10, 15)
        print(f"Snoozing for {snooze} seconds")
        time.sleep(snooze)
        
print("Done scraping all units")
# Out:
# Scraping 1 of 24
# Snoozing for 10 seconds
# Scraping 2 of 24
# Snoozing for 10 seconds
# Scraping 3 of 24
# Snoozing for 12 seconds
# Scraping 4 of 24
# Snoozing for 10 seconds
# Scraping 5 of 24
# Snoozing for 12 seconds
# Scraping 6 of 24
# Snoozing for 10 seconds
# Scraping 7 of 24
# Snoozing for 13 seconds
# Scraping 8 of 24
# Snoozing for 11 seconds
# Scraping 9 of 24
# Snoozing for 11 seconds
# Scraping 10 of 24
# Snoozing for 10 seconds
# Scraping 11 of 24
# Snoozing for 12 seconds
# Scraping 12 of 24
# Snoozing for 13 seconds
# Scraping 13 of 24
# MR was busted or had no table
# Snoozing for 11 seconds
# Scraping 14 of 24
# Snoozing for 11 seconds
# Scraping 15 of 24
# Snoozing for 13 seconds
# Scraping 16 of 24
# Snoozing for 10 seconds
# Scraping 17 of 24
# Snoozing for 11 seconds
# Scraping 18 of 24
# Snoozing for 10 seconds
# Scraping 19 of 24
# Snoozing for 11 seconds
# Scraping 20 of 24
# Snoozing for 11 seconds
# Scraping 21 of 24
# Snoozing for 12 seconds
# Scraping 22 of 24
# Snoozing for 14 seconds
# Scraping 23 of 24
# Snoozing for 14 seconds
# Scraping 24 of 24
# WRGS was busted or had no table
# Snoozing for 13 seconds
# Done scraping all units

# %%
broken_url
# Out:
# ['https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=MR&type=CRI',
#  'https://infopost.enbridge.com/InfoPost/NoticesList.asp?pipe=WRGS&type=CRI']

# %%
df_list[4]
# Out:
#                Notice Type        Posted Date/Time Notice Effective Date/Time  \
# 0      Capacity Constraint  10/23/2023 04:40:01 PM     10/24/2023 09:00:00 AM
# 1      Capacity Constraint  10/22/2023 03:13:24 PM     10/23/2023 09:00:00 AM
# 2      Capacity Constraint  10/21/2023 03:40:56 PM     10/21/2023 03:40:56 PM
# 3      Capacity Constraint  10/21/2023 03:39:01 PM     10/22/2023 09:00:00 AM
# 4   Computer System Status  10/12/2023 03:45:00 PM     10/12/2023 03:45:00 PM
# 5   Computer System Status  10/04/2023 08:15:00 AM     10/10/2023 08:00:00 AM
# 6   Computer System Status  10/02/2023 04:00:00 PM     10/13/2023 09:00:00 AM
# 7      Capacity Constraint  09/19/2023 02:34:58 PM     09/20/2023 09:00:00 AM
# 8      Capacity Constraint  09/18/2023 03:05:16 PM     09/19/2023 09:00:00 AM
# 9      Capacity Constraint  09/14/2023 03:35:39 PM     09/14/2023 03:35:39 PM
# 10     Capacity Constraint  09/14/2023 03:27:00 PM     09/15/2023 09:00:00 AM
# 11     Capacity Constraint  09/14/2023 03:20:03 PM     09/14/2023 03:20:03 PM
# 12  Computer System Status  09/05/2023 02:00:00 PM     10/13/2023 10:00:00 PM
# 13  Computer System Status  08/15/2023 07:55:00 AM     08/15/2023 08:00:00 AM
# 14             Maintenance  08/10/2023 08:00:00 AM     08/10/2023 08:00:00 AM
# 15     Capacity Constraint  07/26/2023 01:03:24 PM     07/26/2023 01:03:24 PM
# 16           Force Majeure  07/26/2023 01:00:40 PM     07/26/2023 01:00:40 PM
#
#       Notice End Date/Time  Notice Identifier  \
# 0   10/25/2023 09:00:00 AM             139541
# 1   10/24/2023 09:00:00 AM             139497
# 2   10/22/2023 09:00:00 AM             139460
# 3   10/23/2023 09:00:00 AM             139459
# 4   10/24/2023 03:45:00 PM             139075
# 5   10/13/2023 08:00:00 AM             138674
# 6   10/15/2023 11:00:00 PM             138606
# 7   09/21/2023 09:00:00 AM             138033
# 8   09/20/2023 09:00:00 AM             138002
# 9   09/15/2023 09:00:00 AM             137888
# 10  09/16/2023 09:00:00 AM             137886
# 11  09/15/2023 09:00:00 AM             137884
# 12  10/15/2023 09:00:00 AM             137508
# 13  11/13/2023 08:00:00 AM             136762
# 14  08/13/2023 04:17:16 PM             136569
# 15  10/24/2023 01:03:24 PM             136067
# 16  10/24/2023 01:00:40 PM             136066
#
#                                               Subject  Response Date/Time unit
# 0              EGAN Storage Conditions for 10/24/2023                 NaN   EG
# 1              Egan Storage Conditions for 10/23/2023                 NaN   EG
# 2   Egan Storage Conditions for 10/21/2023 -- INTR...                 NaN   EG
# 3              Egan Storage Conditions for 10/22/2023                 NaN   EG
# 4   LINK System Maintenance the weekend of October...                 NaN   EG
# 5              LINK Application Testing on October 11                 NaN   EG
# 6   LINK System Maintenance scheduled for October ...                 NaN   EG
# 7               Egan Storage Conditions for 9/20/2023                 NaN   EG
# 8               Egan Storage Conditions for 9/19/2023                 NaN   EG
# 9   Egan Storage Conditions for 9/14/2023 -- INTRA...                 NaN   EG
# 10              Egan Storage Conditions for 9/15/2023                 NaN   EG
# 11  Egan Storage Conditions for 9/14/2023 -- INTRADAY                 NaN   EG
# 12  LINK System Maintenance moved from September 1...                 NaN   EG
# 13     LINK System Downtime Due to System Maintenance                 NaN   EG
# 14                            Measurement Data Outage                 NaN   EG
# 15  MR 45101 - ANR - STORAGE, LA (D40102/R40101) U...                 NaN   EG
# 16  MR 45101 - ANR - STORAGE, LA (D40102/R40101) F...                 NaN   EG

# %%
final_df = pd.concat(df_list).reset_index()

# %%
final_df
# Out:
#       index          Notice Type        Posted Date/Time  \
# 0         0  Capacity Constraint  10/23/2023 03:36:53 PM
# 1         1  Capacity Constraint  10/22/2023 03:05:11 PM
# 2         2  Capacity Constraint  10/21/2023 03:29:00 PM
# 3         3  Capacity Constraint  10/20/2023 03:41:37 PM
# 4         4  Capacity Constraint  10/19/2023 03:10:00 PM
# ...     ...                  ...                     ...
# 1035     93  Capacity Constraint  07/30/2023 02:33:55 PM
# 1036     94  Capacity Constraint  07/29/2023 02:40:35 PM
# 1037     95  Capacity Constraint  07/28/2023 03:42:50 PM
# 1038     96  Capacity Constraint  07/27/2023 02:25:34 PM
# 1039     97  Capacity Constraint  07/26/2023 02:39:33 PM
#
#      Notice Effective Date/Time    Notice End Date/Time  Notice Identifier  \
# 0        10/24/2023 09:00:00 AM  10/25/2023 09:00:00 AM             139536
# 1        10/23/2023 09:00:00 AM  10/24/2023 09:00:00 AM             139482
# 2        10/22/2023 09:00:00 AM  10/23/2023 09:00:00 AM             139455
# 3        10/21/2023 09:00:00 AM  10/22/2023 09:00:00 AM             139420
# 4        10/20/2023 09:00:00 AM  10/21/2023 09:00:00 AM             139374
# ...                         ...                     ...                ...
# 1035     07/31/2023 09:00:00 AM  08/01/2023 09:00:00 AM             136195
# 1036     07/30/2023 09:00:00 AM  07/31/2023 09:00:00 AM             136174
# 1037     07/29/2023 09:00:00 AM  07/30/2023 09:00:00 AM             136158
# 1038     07/28/2023 09:00:00 AM  07/29/2023 09:00:00 AM             136106
# 1039     07/27/2023 09:00:00 AM  07/28/2023 09:00:00 AM             136075
#
#                                      Subject  Response Date/Time unit
# 0     AGT Pipeline Conditions for 10/24/2023                 NaN   AG
# 1     AGT Pipeline Conditions for 10/23/2023                 NaN   AG
# 2     AGT Pipeline Conditions for 10/22/2023                 NaN   AG
# 3     AGT Pipeline Conditions for 10/21/2023                 NaN   AG
# 4     AGT Pipeline Conditions for 10/20/2023                 NaN   AG
# ...                                      ...                 ...  ...
# 1035   VCP Pipeline Conditions for 7/31/2023                 NaN  VCP
# 1036   VCP Pipeline Conditions for 7/30/2023                 NaN  VCP
# 1037   VCP Pipeline Conditions for 7/29/2023                 NaN  VCP
# 1038   VCP Pipeline Conditions for 7/28/2023                 NaN  VCP
# 1039   VCP Pipeline Conditions for 7/27/2023                 NaN  VCP
#
# [1040 rows x 9 columns]

# %%
final_df.sample(20)
# Out:
#       index          Notice Type        Posted Date/Time  \
# 56       56  Capacity Constraint  09/13/2023 03:05:00 PM
# 855      90  Capacity Constraint  08/27/2023 02:56:00 PM
# 33       33  Capacity Constraint  09/30/2023 03:13:53 PM
# 552      92  Capacity Constraint  08/08/2023 02:45:16 PM
# 292       2  Capacity Constraint  10/21/2023 03:53:18 PM
# 555      95  Capacity Constraint  08/05/2023 02:49:15 PM
# 1020     78  Capacity Constraint  08/11/2023 02:37:00 PM
# 115     115  Capacity Constraint  08/01/2023 02:53:19 PM
# 239      78  Capacity Constraint  08/24/2023 02:12:51 PM
# 670       9  Capacity Constraint  10/14/2023 03:35:19 PM
# 1039     97  Capacity Constraint  07/26/2023 02:39:33 PM
# 820      55  Capacity Constraint  09/22/2023 03:55:32 PM
# 988      46  Capacity Constraint  09/10/2023 02:42:00 PM
# 163       2  Capacity Constraint  10/22/2023 03:06:32 PM
# 396      43  Capacity Constraint  09/21/2023 03:11:48 PM
# 73       73  Capacity Constraint  09/03/2023 02:37:30 PM
# 341       3    Operational Alert  09/29/2023 10:52:00 AM
# 436      83  Capacity Constraint  08/16/2023 02:41:55 PM
# 166       5  Capacity Constraint  10/20/2023 02:41:15 PM
# 462       2  Capacity Constraint  10/21/2023 03:01:36 PM
#
#      Notice Effective Date/Time    Notice End Date/Time  Notice Identifier  \
# 56       09/14/2023 09:00:00 AM  09/15/2023 09:00:00 AM             137812
# 855      08/28/2023 09:00:00 AM  08/29/2023 09:00:00 AM             137219
# 33       09/30/2023 03:13:53 PM  12/29/2023 03:13:53 PM             138513
# 552      08/09/2023 09:00:00 AM  08/10/2023 09:00:00 AM             136509
# 292      10/22/2023 09:00:00 AM  10/23/2023 09:00:00 AM             139463
# 555      08/06/2023 09:00:00 AM  08/07/2023 09:00:00 AM             136420
# 1020     08/12/2023 09:00:00 AM  08/13/2023 09:00:00 AM             136639
# 115      08/02/2023 09:00:00 AM  08/03/2023 09:00:00 AM             136290
# 239      08/25/2023 09:00:00 AM  08/26/2023 09:00:00 AM             137114
# 670      10/15/2023 09:00:00 AM  10/16/2023 09:00:00 AM             139173
# 1039     07/27/2023 09:00:00 AM  07/28/2023 09:00:00 AM             136075
# 820      09/23/2023 09:00:00 AM  09/24/2023 09:00:00 AM             138240
# 988      09/11/2023 09:00:00 AM  09/12/2023 09:00:00 AM             137709
# 163      10/23/2023 09:00:00 AM  10/24/2023 09:00:00 AM             139494
# 396      09/22/2023 09:00:00 AM  09/23/2023 09:00:00 AM             138181
# 73       09/04/2023 09:00:00 AM  09/05/2023 09:00:00 AM             137457
# 341      09/29/2023 10:52:00 AM  12/28/2023 10:52:00 AM             138462
# 436      08/17/2023 09:00:00 AM  08/18/2023 09:00:00 AM             136834
# 166      10/21/2023 09:00:00 AM  10/22/2023 09:00:00 AM             139403
# 462      10/22/2023 09:00:00 AM  10/23/2023 09:00:00 AM             139434
#
#                                                 Subject  Response Date/Time  \
# 56                AGT Pipeline Conditions for 9/14/2023                 NaN
# 855                TE Pipeline Conditions for 8/28/2023                 NaN
# 33    Cromwell to Chaplin ML Valve Section 4 Investi...                 NaN
# 552               SESH Pipeline Conditions for 8/9/2023                 NaN
# 292        Moss Bluff Storage Conditions for 10/22/2023                 NaN
# 555               SESH Pipeline Conditions for 8/6/2023                 NaN
# 1020              VCP Pipeline Conditions for 8/12/2023                 NaN
# 115                AGT Pipeline Conditions for 8/2/2023                 NaN
# 239              ETNG Pipeline Conditions for 8/25/2023                 NaN
# 670                SR Storage Conditions for 10/15/2023                 NaN
# 1039              VCP Pipeline Conditions for 7/27/2023                 NaN
# 820                TE Pipeline Conditions for 9/23/2023                 NaN
# 988               VCP Pipeline Conditions for 9/11/2023                 NaN
# 163             ETNG Pipeline Conditions for 10/23/2023                 NaN
# 396             NEXUS Pipeline Conditions for 9/22/2023                 NaN
# 73                 AGT Pipeline Conditions for 9/4/2023                 NaN
# 341        Title: Planned Maintenance at Ship Shoal 207                 NaN
# 436             NEXUS Pipeline Conditions for 8/17/2023                 NaN
# 166             ETNG Pipeline Conditions for 10/21/2023                 NaN
# 462             SESH Pipeline Conditions for 10/22/2023                 NaN
#
#       unit
# 56      AG
# 855     TE
# 33      AG
# 552   SESH
# 292     MB
# 555   SESH
# 1020   VCP
# 115     AG
# 239     ET
# 670     SR
# 1039   VCP
# 820     TE
# 988    VCP
# 163     ET
# 396   NXUS
# 73      AG
# 341    NPC
# 436   NXUS
# 166     ET
# 462   SESH
